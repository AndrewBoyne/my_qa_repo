# %%
import pandas as pd

# %% [raw]
# trips = pd.read_csv("seattle_cycle_trips.csv")

# %%
trips
# Out:
#         Unnamed: 0  trip_id            starttime          stoptime    bikeid  \
# 0                0      431  2014-10-13 10:31:00  10/13/2014 10:48  SEA00298
# 1                1      432  2014-10-13 10:32:00  10/13/2014 10:48  SEA00195
# 2                2      433  2014-10-13 10:33:00  10/13/2014 10:48  SEA00486
# 3                3      434  2014-10-13 10:34:00  10/13/2014 10:48  SEA00333
# 4                4      435  2014-10-13 10:34:00  10/13/2014 10:49  SEA00202
# ...            ...      ...                  ...               ...       ...
# 286853      286853   255241  2016-08-31 23:34:00   8/31/2016 23:45  SEA00201
# 286854      286854   255242  2016-08-31 23:48:00  09/01/2016 00:20  SEA00247
# 286855      286855   255243  2016-08-31 23:47:00  09/01/2016 00:20  SEA00300
# 286856      286856   255244  2016-08-31 23:49:00  09/01/2016 00:20  SEA00047
# 286857      286857   255245  2016-08-31 23:49:00  09/01/2016 00:20  SEA00442
#
# ...

# %%
trips['starttime'] = pd.to_datetime(trips['starttime']) # convert starttime to date/time

# %%
trips.dtypes
# Out:
# Unnamed: 0                    int64
# trip_id                       int64
# starttime            datetime64[ns]
# stoptime                     object
# bikeid                       object
# tripduration                float64
# from_station_name            object
# to_station_name              object
# from_station_id              object
# to_station_id                object
# usertype                     object
# gender                       object
# birthyear                    object
# dtype: object

# %%
trips.to_csv('seattle_cycle_trips_dates.csv') # save new file

# %%
trips.dtypes
# Out:
# Unnamed: 0                    int64
# trip_id                       int64
# starttime            datetime64[ns]
# stoptime                     object
# bikeid                       object
# tripduration                float64
# from_station_name            object
# to_station_name              object
# from_station_id              object
# to_station_id                object
# usertype                     object
# gender                       object
# birthyear                    object
# dtype: object

# %%
df['month_only'] = trips['starttime'].dt.month # new column with month only

# %%
df.tail(5)
# Out:
#         Unnamed: 0  trip_id            starttime          stoptime    bikeid  \
# 286853      286853   255241  2016-08-31 23:34:00   8/31/2016 23:45  SEA00201
# 286854      286854   255242  2016-08-31 23:48:00  09/01/2016 00:20  SEA00247
# 286855      286855   255243  2016-08-31 23:47:00  09/01/2016 00:20  SEA00300
# 286856      286856   255244  2016-08-31 23:49:00  09/01/2016 00:20  SEA00047
# 286857      286857   255245  2016-08-31 23:49:00  09/01/2016 00:20  SEA00442
#
#         tripduration                       from_station_name  \
# 286853       679.532                 Harvard Ave & E Pine St
# 286854      1965.418  Cal Anderson Park / 11th Ave & Pine St
# 286855      1951.173  Cal Anderson Park / 11th Ave & Pine St
# 286856      1883.299  Cal Anderson Park / 11th Ave & Pine St
# 286857      1896.031  Cal Anderson Park / 11th Ave & Pine St
#
#               to_station_name from_station_id to_station_id  \
# 286853    2nd Ave & Spring St           CH-09        CBD-06
# ...

# %%
df.head(1)
# Out:
#    Unnamed: 0  trip_id            starttime          stoptime    bikeid  \
# 0           0      431  2014-10-13 10:31:00  10/13/2014 10:48  SEA00298
#
#    tripduration    from_station_name  \
# 0       985.935  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
#
#   to_station_id usertype gender birthyear  month_only
# 0         PS-04   Member   Male      1960          10

# %%
df.to_csv('seattle_cycle_trips_months.csv')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# trip_id                int64
# starttime             object
# stoptime              object
# bikeid                object
# tripduration         float64
# from_station_name     object
# to_station_name       object
# from_station_id       object
# to_station_id         object
# usertype              object
# gender                object
# birthyear             object
# month_only             int64
# dtype: object

# %%
trips.dtypes
# Out:
# Unnamed: 0                    int64
# trip_id                       int64
# starttime            datetime64[ns]
# stoptime                     object
# bikeid                       object
# tripduration                float64
# from_station_name            object
# to_station_name              object
# from_station_id              object
# to_station_id                object
# usertype                     object
# gender                       object
# birthyear                    object
# dtype: object

# %%
df['time_only'] = trips['starttime'].dt.time # convert to date / time

# %%
df.head(1)
# Out:
#    Unnamed: 0  trip_id            starttime          stoptime    bikeid  \
# 0           0      431  2014-10-13 10:31:00  10/13/2014 10:48  SEA00298
#
#    tripduration    from_station_name  \
# 0       985.935  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
#
#   to_station_id usertype gender birthyear  month_only time_only
# 0         PS-04   Member   Male      1960          10  10:31:00

# %%
df['time_only'] = trips['starttime'].dt.strftime('%H') # convert to hour only

# %%
df.head(1)
# Out:
#    Unnamed: 0  trip_id            starttime          stoptime    bikeid  \
# 0           0      431  2014-10-13 10:31:00  10/13/2014 10:48  SEA00298
#
#    tripduration    from_station_name  \
# 0       985.935  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
#
#   to_station_id usertype gender birthyear  month_only time_only
# 0         PS-04   Member   Male      1960          10        10

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# trip_id                int64
# starttime             object
# stoptime              object
# bikeid                object
# tripduration         float64
# from_station_name     object
# to_station_name       object
# from_station_id       object
# to_station_id         object
# usertype              object
# gender                object
# birthyear             object
# month_only             int64
# time_only             object
# dtype: object

# %%
df.to_csv('seattle_cycle_trips_hours.csv') # save new file

# %%
trips.head(5) # now trying to work out the differences between the two columns from and to
# Out:
#    Unnamed: 0  trip_id           starttime          stoptime    bikeid  \
# 0           0      431 2014-10-13 10:31:00  10/13/2014 10:48  SEA00298
# 1           1      432 2014-10-13 10:32:00  10/13/2014 10:48  SEA00195
# 2           2      433 2014-10-13 10:33:00  10/13/2014 10:48  SEA00486
# 3           3      434 2014-10-13 10:34:00  10/13/2014 10:48  SEA00333
# 4           4      435 2014-10-13 10:34:00  10/13/2014 10:49  SEA00202
#
#    tripduration    from_station_name  \
# 0       985.935  2nd Ave & Spring St
# 1       926.375  2nd Ave & Spring St
# 2       883.831  2nd Ave & Spring St
# 3       865.937  2nd Ave & Spring St
# 4       923.923  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 1  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# 2  Occidental Park / Occidental Ave S & S Washing...          CBD-06
# ...

# %%
trips.head(1)
# Out:
#    Unnamed: 0  trip_id           starttime          stoptime    bikeid  \
# 0           0      431 2014-10-13 10:31:00  10/13/2014 10:48  SEA00298
#
#    tripduration    from_station_name  \
# 0       985.935  2nd Ave & Spring St
#
#                                      to_station_name from_station_id  \
# 0  Occidental Park / Occidental Ave S & S Washing...          CBD-06
#
#   to_station_id usertype gender birthyear
# 0         PS-04   Member   Male      1960

# %%
df = trips.('from_station_name')
# Out:
#   Cell In[58], line 1
#     df = trips.('from_station_name')
#                ^
# SyntaxError: invalid syntax

# %%
trips_from_and_to = trips[['from_station_name', 'to_station_name']] # I've separated the two 
# columns from the main table.

# %%
trips_from_and_to.head(1) # I now need to work out how many do not finish at the same place
# Out:
#      from_station_name                                    to_station_name
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...

# %%
trips_diff = trips_from_and_to.query('from_station_name != to_station_name')

# %%
trips_diff.head(1)
# Out:
#      from_station_name                                    to_station_name
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...

# %%
trips_diff.to_csv('seattle_cycle_trips_diff_stations.csv')
