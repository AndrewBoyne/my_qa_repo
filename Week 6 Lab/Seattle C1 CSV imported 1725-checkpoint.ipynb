# %%
import pandas as pd

# %%
cycles_station = pd.read_csv("Seattle_cycles_station.csv")

# %%
cycle_stations.head(10)
# Out:
#   station_id                            name        lat        long  \
# 0      BT-01              3rd Ave & Broad St  47.618418 -122.350964
# 1      BT-03               2nd Ave & Vine St  47.615829 -122.348564
# 2      BT-04          6th Ave & Blanchard St  47.616094 -122.341102
# 3      BT-05          2nd Ave & Blanchard St  47.613110 -122.344208
# 4     CBD-03              7th Ave & Union St  47.610731 -122.332447
# 5     CBD-04              Union St & 4th Ave  47.609221 -122.335596
# 6     CBD-05             1st Ave & Marion St  47.604058 -122.335800
# 7     CBD-06             2nd Ave & Spring St  47.605950 -122.335768
# 8     CBD-07  City Hall / 4th Ave & James St  47.603509 -122.330409
# 9     CBD-13               2nd Ave & Pine St  47.610185 -122.339641
#
#   install_date  install_dockcount modification_date  current_dockcount  \
# 0   10/13/2014                 18               NaN                 18
# 1   10/13/2014                 16               NaN                 16
# ...

# %%
cycle_trips = pd.read_csv("Seattle_cycles_trip.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_4112\2970188690.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   cycle_trips = pd.read_csv("Seattle_cycles_trip.csv")

# %%
cycle_trips.head(10)
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
# 5      436  10/13/2014 10:34  10/13/2014 10:47  SEA00337       808.805
# 6      437  10/13/2014 11:35  10/13/2014 11:45  SEA00202       596.715
# 7      438  10/13/2014 11:35  10/13/2014 11:45  SEA00311       592.131
# 8      439  10/13/2014 11:35  10/13/2014 11:45  SEA00486       586.347
# 9      440  10/13/2014 11:35  10/13/2014 11:45  SEA00434       587.634
#
#                                    from_station_name  \
# 0                                2nd Ave & Spring St
# 1                                2nd Ave & Spring St
# ...

# %%
cycles_station
# Out:
#   Cell In[19], line 1
#     cycles_station define
#                    ^
# SyntaxError: invalid syntax

# %%
total_trips = [[from_station_name + to_station_name]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 total_trips = [[from_station_name + to_station_name]]
#
# NameError: name 'from_station_name' is not defined

# %%
cycle_stations.head(5)
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
# 3      BT-05  2nd Ave & Blanchard St  47.613110 -122.344208   10/13/2014
# 4     CBD-03      7th Ave & Union St  47.610731 -122.332447   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date
# 0                 18               NaN                 18               NaN
# 1                 16               NaN                 16               NaN
# 2                 16               NaN                 16               NaN
# 3                 14               NaN                 14               NaN
# 4                 20               NaN                 20               NaN

# %%
big_stations = cycle_stations[cycle_stations['install_dockcount']>19]

# %%
big_stations
# Out:
#    station_id                                               name        lat  \
# 4      CBD-03                                 7th Ave & Union St  47.610731
# 6      CBD-05                                1st Ave & Marion St  47.604058
# 7      CBD-06                                2nd Ave & Spring St  47.605950
# 8      CBD-07                     City Hall / 4th Ave & James St  47.603509
# 17      CH-08             Cal Anderson Park / 11th Ave & Pine St  47.615486
# 22     DPD-03  Children's Hospital / Sandpoint Way NE & 40th ...  47.663509
# 27      FH-04      Seattle University / E Columbia St & 12th Ave  47.609239
# 36     SLU-16                                  Pine St & 9th Ave  47.613715
# 38     SLU-18                             Dexter Ave & Denny Way  47.618285
# 40     SLU-20                             Terry Ave & Stewart St  47.616260
# 41     SLU-21                              Mercer St & 9th Ave N  47.624769
# ...
