# %%
import pandas as pd

# %%
df=pd.read_csv("ufo_sightings.csv")

# %%
df.head()
# Out:
#   Location.City Location.State Location.Country Data.Shape  \
# 0  anchor point             AK               US       disk
# 1     anchorage             AK               US   changing
# 2     anchorage             AK               US   changing
# 3     anchorage             AK               US      cigar
# 4     anchorage             AK               US     circle
#
#    Data.Encounter duration                           Data.Description excerpt  \
# 0                    300.0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...
# 1                  21600.0  We could observe red lights dancing across the...
# 2                    600.0  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...
# 3                     15.0  I explained away the first time I thought I se...
# 4                    300.0  Orange circles &quot;climbing&quot; then fadin...
#
#    Location.Coordinates.Latitude   Location.Coordinates.Longitude   \
# 0                       59.776667                      -151.831389
# ...

# %%
#Check what type of date we have?  No Nulls - useful
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60632 entries, 0 to 60631
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Location.City                    60632 non-null  object
#  1   Location.State                   60632 non-null  object
#  2   Location.Country                 60632 non-null  object
#  3   Data.Shape                       60632 non-null  object
#  4   Data.Encounter duration          60632 non-null  float64
#  5   Data.Description excerpt         60632 non-null  object
#  6   Location.Coordinates.Latitude    60632 non-null  float64
#  7   Location.Coordinates.Longitude   60632 non-null  float64
#  8   Dates.Sighted.Year               60632 non-null  int64
#  9   Dates.Sighted.Month              60632 non-null  int64
#  10  Date.Sighted.Day                 60632 non-null  int64
#  11  Dates.Sighted.Hour               60632 non-null  int64
# ...

# %%
df.sort_values(by='Data.Shape').head()
# Out:
#       Location.City Location.State Location.Country Data.Shape  \
# 12008        aurora             CO               US    changed
# 3569     tumacacori             AZ               US   changing
# 46503        lititz             PA               US   changing
# 46502        lititz             PA               US   changing
# 1189    little rock             AR               US   changing
#
#        Data.Encounter duration  \
# 12008                   3600.0
# 3569                     300.0
# 46503                     60.0
# 46502                    240.0
# 1189                      15.0
#
#                                 Data.Description excerpt  \
# 12008  Obj. hovered 100 ft above car.  Red&#44 blue l...
# 3569   Bright Amber Light over the Tumacacori Mtns&#4...
# 46503  Orange/red sphere very large changed shape and...
# 46502  Many red objects flying in different direction...
# 1189   Green lights above West Little Rock. 500 Light...
#
# ...

# %%
df.head()
# Out:
#   Location.City Location.State Location.Country Data.Shape  \
# 0  anchor point             AK               US       disk
# 1     anchorage             AK               US   changing
# 2     anchorage             AK               US   changing
# 3     anchorage             AK               US      cigar
# 4     anchorage             AK               US     circle
#
#    Data.Encounter duration                           Data.Description excerpt  \
# 0                    300.0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...
# 1                  21600.0  We could observe red lights dancing across the...
# 2                    600.0  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...
# 3                     15.0  I explained away the first time I thought I se...
# 4                    300.0  Orange circles &quot;climbing&quot; then fadin...
#
#    Location.Coordinates.Latitude   Location.Coordinates.Longitude   \
# 0                       59.776667                      -151.831389
# ...

# %%
#Check what types of shape we have
df['Data.Shape'].unique()
# Out:
# array(['disk', 'changing', 'cigar', 'circle', 'cylinder', 'egg',
#        'fireball', 'flash', 'formation', 'light', 'other', 'oval',
#        'sphere', 'teardrop', 'triangle', 'unknown', 'rectangle',
#        'diamond', 'cone', 'chevron', 'cross', 'round', 'flare', 'changed',
#        'delta', 'pyramid', 'hexagon', 'crescent'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60632 entries, 0 to 60631
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Location.City                    60632 non-null  object
#  1   Location.State                   60632 non-null  object
#  2   Location.Country                 60632 non-null  object
#  3   Data.Shape                       60632 non-null  object
#  4   Data.Encounter duration          60632 non-null  float64
#  5   Data.Description excerpt         60632 non-null  object
#  6   Location.Coordinates.Latitude    60632 non-null  float64
#  7   Location.Coordinates.Longitude   60632 non-null  float64
#  8   Dates.Sighted.Year               60632 non-null  int64
#  9   Dates.Sighted.Month              60632 non-null  int64
#  10  Date.Sighted.Day                 60632 non-null  int64
#  11  Dates.Sighted.Hour               60632 non-null  int64
# ...

# %%
df=df.rename(columns={'Location.City':'City'})

# %%
df=df.rename(columns={'Location.City':'City', 'Location.State':'State', 'Location.Country':'Country','Data.Shape':'Shape', 'Data.Encounter duration':'Duration','Data.Description excerpt':'Comments','Location.Coordinates.Latitude':'Lat','Location.Coordinates.Longitude':'Long','Dates.Sighted.Year':'Year_Sighted','Dates.Sighted.Month':'Month_Sighted','Date.Sighted.Day':'Day_Sighted','Dates.Sighted.Hour':'Hour_Sighted','Dates.Sighted.Minute':'Minute_Sighted'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60632 entries, 0 to 60631
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   City                             60632 non-null  object
#  1   State                            60632 non-null  object
#  2   Country                          60632 non-null  object
#  3   Shape                            60632 non-null  object
#  4   Duration                         60632 non-null  float64
#  5   Comments                         60632 non-null  object
#  6   Location.Coordinates.Latitude    60632 non-null  float64
#  7   Location.Coordinates.Longitude   60632 non-null  float64
#  8   Year_Sighted                     60632 non-null  int64
#  9   Month_Sighted                    60632 non-null  int64
#  10  Day_Sighted                      60632 non-null  int64
#  11  Hour_Sighted                     60632 non-null  int64
# ...

# %%
df['Latitude']=df['Location.Coordinates.Latitude'] #Can't seem to change the name of 
#these columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Location.Coordinates.Latitude'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.head()
# Out:
#            City State Country     Shape  Duration  \
# 0  anchor point    AK      US      disk     300.0
# 1     anchorage    AK      US  changing   21600.0
# 2     anchorage    AK      US  changing     600.0
# 3     anchorage    AK      US     cigar      15.0
# 4     anchorage    AK      US    circle     300.0
#
#                                             Comments  \
# 0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...
# 1  We could observe red lights dancing across the...
# 2  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...
# 3  I explained away the first time I thought I se...
# 4  Orange circles &quot;climbing&quot; then fadin...
#
#    Location.Coordinates.Latitude   Location.Coordinates.Longitude   \
# 0                       59.776667                      -151.831389
# 1                       61.218056                      -149.900278
# 2                       61.218056                      -149.900278
# 3                       61.218056                      -149.900278
# ...
