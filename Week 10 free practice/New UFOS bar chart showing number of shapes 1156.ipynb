# %%
import pandas as pd

# %%
#As I was unable to amend the header columnswith the dots so I amended the spread sheet and saved as UFOs
df=pd.read_csv("UFOs.csv")

# %%
df.head()
# Out:
#            City State Country     Shape  Encounter duration  \
# 0  anchor point    AK      US      disk               300.0
# 1     anchorage    AK      US  changing             21600.0
# 2     anchorage    AK      US  changing               600.0
# 3     anchorage    AK      US     cigar                15.0
# 4     anchorage    AK      US    circle               300.0
#
#                                             Comments  Latitude   Longitude   \
# 0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...  59.776667 -151.831389
# 1  We could observe red lights dancing across the...  61.218056 -149.900278
# 2  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...  61.218056 -149.900278
# 3  I explained away the first time I thought I se...  61.218056 -149.900278
# 4  Orange circles &quot;climbing&quot; then fadin...  61.218056 -149.900278
#
#    Year  Month  .Day  Hour  Minute  Dates.Documented.Year  \
# 0  2005      5    24    18      30                   2005
# ...

# %%
df=df.rename(columns={'Encounter duration':'Duration','.Day':'Day'})

# %%
df.head()
# Out:
#            City State Country     Shape  Duration  \
# 0  anchor point    AK      US      disk     300.0
# 1     anchorage    AK      US  changing   21600.0
# 2     anchorage    AK      US  changing     600.0
# 3     anchorage    AK      US     cigar      15.0
# 4     anchorage    AK      US    circle     300.0
#
#                                             Comments  Latitude   Longitude   \
# 0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...  59.776667 -151.831389
# 1  We could observe red lights dancing across the...  61.218056 -149.900278
# 2  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...  61.218056 -149.900278
# 3  I explained away the first time I thought I se...  61.218056 -149.900278
# 4  Orange circles &quot;climbing&quot; then fadin...  61.218056 -149.900278
#
#    Year  Month  Day  Hour  Minute  Dates.Documented.Year  \
# 0  2005      5   24    18      30                   2005
# 1  2000     12   31    21       0                   2001
# ...

# %%
# Drop unnecessary columns
df.drop(['Dates.Documented.Year','Dates.Documented.Month','Dates.Documented.Day'], axis=1, inplace=True)

# %%
df.head()
# Out:
#            City State Country     Shape  Duration  \
# 0  anchor point    AK      US      disk     300.0
# 1     anchorage    AK      US  changing   21600.0
# 2     anchorage    AK      US  changing     600.0
# 3     anchorage    AK      US     cigar      15.0
# 4     anchorage    AK      US    circle     300.0
#
#                                             Comments  Latitude   Longitude   \
# 0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...  59.776667 -151.831389
# 1  We could observe red lights dancing across the...  61.218056 -149.900278
# 2  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...  61.218056 -149.900278
# 3  I explained away the first time I thought I se...  61.218056 -149.900278
# 4  Orange circles &quot;climbing&quot; then fadin...  61.218056 -149.900278
#
#    Year  Month  Day  Hour  Minute
# 0  2005      5   24    18      30
# 1  2000     12   31    21       0
# 2  2006     10   23    21       3
# 3  2014      3   29    20      45
# ...

# %%
# What are the entries in Shape?
df.groupby(['Shape']).count()
# Out:
#             City  State  Country  Duration  Comments  Latitude   Longitude   \
# Shape
# changed        1      1        1         1         1          1           1
# changing    1517   1517     1517      1517      1517       1517        1517
# chevron      774    774      774       774       774        774         774
# cigar       1569   1569     1569      1569      1569       1569        1569
# circle      5890   5890     5890      5890      5890       5890        5890
# cone         235    235      235       235       235        235         235
# crescent       1      1        1         1         1          1           1
# cross        177    177      177       177       177        177         177
# cylinder     977    977      977       977       977        977         977
# delta          6      6        6         6         6          6           6
# diamond      884    884      884       884       884        884         884
# ...

# %%
# Create new column with totals of the different Shapes
df['Shape_count']=df['Shape'].groupby(df['Shape']).transform('count')

# %%
df.head()
# Out:
#            City State Country     Shape  Duration  \
# 0  anchor point    AK      US      disk     300.0
# 1     anchorage    AK      US  changing   21600.0
# 2     anchorage    AK      US  changing     600.0
# 3     anchorage    AK      US     cigar      15.0
# 4     anchorage    AK      US    circle     300.0
#
#                                             Comments  Latitude   Longitude   \
# 0  Large UFO over Mt. ILIAMNA Alaska.  ((NUFORC N...  59.776667 -151.831389
# 1  We could observe red lights dancing across the...  61.218056 -149.900278
# 2  INTENSE AMBER-ORANGE HONEYCOMB SHAPED DUAL HOR...  61.218056 -149.900278
# 3  I explained away the first time I thought I se...  61.218056 -149.900278
# 4  Orange circles &quot;climbing&quot; then fadin...  61.218056 -149.900278
#
#    Year  Month  Day  Hour  Minute  Shape_count
# 0  2005      5   24    18      30         3853
# 1  2000     12   31    21       0         1517
# 2  2006     10   23    21       3         1517
# ...

# %%
new_columns=['Shape', 'Shape_count']

# %%
shapes=df[new_columns]

# %%
shapes.head()
# Out:
#       Shape  Shape_count
# 0      disk         3853
# 1  changing         1517
# 2  changing         1517
# 3     cigar         1569
# 4    circle         5890

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ax = sns.barplot(x='Shape', y='Shape_count', data = shapes)
plt.xticks(rotation=90)
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), str(int(p.get_height())),
            ha='center', va='bottom', visible=False)
