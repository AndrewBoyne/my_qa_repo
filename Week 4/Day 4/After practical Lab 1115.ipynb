# %% [markdown]
# # Data Visualisation

# %% [markdown]
# # Matplotlib (plt) and Seaborn (sns)

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
import pandas as pd
import numpy as np
df1=pd.read_csv('mortgage_applicants.csv')
df1
# Out:
#      Unnamed: 0   ID  Income      Term  Balance  Debt  Score  Default
# 0             0  567   17626  10 Years     1381   293  228.0    False
# 1             1  523   18959  20 Years      883  1012  187.0    False
# 2             2  544   20560  10 Years      684   898   86.0    False
# 3             3  370   21894  10 Years      748    85    NaN    False
# 4             4  756   24430  10 Years     1224    59  504.0    False
# ..          ...  ...     ...       ...      ...   ...    ...      ...
# 851         851   71   30191  20 Years     1319  3880   55.0     True
# 852         852  932   41669  20 Years     1385    32  780.0    False
# 853         853   39   36816  20 Years     1868  3123  366.0     True
# 854         854  283   42145  20 Years     1447  2498  422.0    False
# 855         855  847   30594  20 Years     1216  2473  179.0     True
#
# [856 rows x 8 columns]

# %%
fig, ax=plt.subplots(figsize=(10, 2)) # changes the dimensions of the frame
plt.scatter(df1['Debt'],              # x axis by default
           df1['Balance']);           # y axis by default

# %%
fig, ax=plt.subplots(figsize=(15, 5)) # changes the dimensions of the frame
plt.scatter(df1['Debt'],
           df1['Balance']);

# %%
fig, (ax1, ax2)=plt.subplots(1, 2, figsize=(10, 2)) # 2 rows, 2 columns

# %%
#ax1.set_xlabel - appears at bottom of x axis 
#ax1.set_ylabel - appears to left of y axis
#ax1.set_title - appears above the graphic
#ax1.set-xlim - best to set with a small excess either side of the values otherwise anything which
#ax1.set-ylim - returns a value at the limit (eg £6,000) will not show clearly enough

# %% [markdown]
# ## Seaborn

# %%
df1
# Out:
#      Unnamed: 0   ID  Income      Term  Balance  Debt  Score  Default
# 0             0  567   17626  10 Years     1381   293  228.0    False
# 1             1  523   18959  20 Years      883  1012  187.0    False
# 2             2  544   20560  10 Years      684   898   86.0    False
# 3             3  370   21894  10 Years      748    85    NaN    False
# 4             4  756   24430  10 Years     1224    59  504.0    False
# ..          ...  ...     ...       ...      ...   ...    ...      ...
# 851         851   71   30191  20 Years     1319  3880   55.0     True
# 852         852  932   41669  20 Years     1385    32  780.0    False
# 853         853   39   36816  20 Years     1868  3123  366.0     True
# 854         854  283   42145  20 Years     1447  2498  422.0    False
# 855         855  847   30594  20 Years     1216  2473  179.0     True
#
# [856 rows x 8 columns]

# %%
fig, ax=plt.subplots(figsize=(8, 3))
sns.scatterplot(data=df1,
                x="Debt",
                y='Income',
                hue="Default",
                style='Default',
                ax=ax);

# %%
fig, ax=plt.subplots(figsize=(8, 8))
sns.scatterplot(data=df1,
                x="Debt",
                y='Income',
                hue="Default",
                style='Default',
                ax=ax);

# %%
fig, ax=plt.subplots(figsize=(16, 6))
sns.scatterplot(data=df1,
                x="Debt",
                y='Income',
                hue="Default",
                style='Default',
                ax=ax);
