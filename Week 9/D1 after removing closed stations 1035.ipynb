# %% [markdown]
# ## Wrangling parks data
#
# ### Goals of the Task
#
#
# Each row in the cultural spaces data set is a Seattle venue such as a cinema, art gallery, theatre or music venue.
#
# The aim of this task is to remove cultural spaces from the data that we don’t have location information against, plus any spaces that were closed before the period of our cycle hire data sample. Then, using the range of longitude and latitude found in the cycle hire data, you will eliminate cultural spaces that are not located near cycle hire stations.
#
# After this you will use an aggregation method in pandas to review the number of cultural spaces in your remaining data set, summarizing these venues by neighbourhood and cultural purpose.

# %% [markdown]
# #### Step 1 : use pandas to read the cultural spaces csv as a data frame
# - import pandas as pd
# - use pandas read_csv to create a culturalspaces data frame
# - ensure you are pointing at the correct file path for the data source (you may have to navigate in your notebook!)

# %%
import pandas as pd

# %%
df = pd.read_csv('Seattle_Cultural_Space_Inventory.csv')

# %%
df
# Out:
#                                                Name           Phone  \
# 0                                        10 Degrees             NaN
# 1                             Alki Community Center             NaN
# 2                                   Calypte Gallery             NaN
# 3                       Cassandria Blackmore Studio             NaN
# 4                             Dynamic Sound Service             NaN
# ..                                              ...             ...
# 939                    Illumination Learning Studio  (206) 789-ARTS
# 940                                        Serafina             NaN
# 941                          Eight and Sand Gallery  (206) 304-0394
# 942        University of Washington Mary Gates Hall             NaN
# 943  Bill & Melinda Gates Foundation Visitor Center  (206) 709-3100
#
#                           URL  Square Feet Total   Neighborhood  \
# 0    www.10degreesseattle.com              750.0   Capitol Hill
# 1                         NaN                NaN           Alki
# 2                         NaN                NaN            NaN
# 3                         NaN                NaN            NaN
# 4                         NaN                NaN            NaN
# ..                        ...                ...            ...
# 939           www.ILSKids.com             2500.0  Phinney Ridge
# 940                       NaN                NaN            NaN
# 941      www.eightandsand.com              132.0     Georgetown
# 942                       NaN                NaN            NaN
# 943           www.gatesvc.org            10000.0         Uptown
#
#     Organization Type                       Dominant Discipline  \
# 0                   N                                 Multi-use
# 1                 NaN                          Community Center
# 2                 NaN                                    Visual
# 3                 NaN                                    Visual
# 4                 NaN                                   Studios
# ..                ...                                       ...
# 939                 N       Arts/Cultural Training or Education
# 940               NaN                                     Music
# 941                 N                                    Visual
# 942               NaN       Arts/Cultural Training or Education
# 943                 Y  Arts/Cultural Administration or Advocacy
#
#      Year of Occupation Rent vs Own  Age of Current Building  ...  \
# 0                2011.0           O                   1970.0  ...
# 1                   NaN         NaN                      NaN  ...
# 2                   NaN         NaN                      NaN  ...
# 3                   NaN         NaN                      NaN  ...
# 4                   NaN         NaN                      NaN  ...
# ..                  ...         ...                      ...  ...
# 939              2013.0           R                   1990.0  ...
# 940                 NaN         NaN                      NaN  ...
# 941              2013.0           R                   1901.0  ...
# 942                 NaN         NaN                      NaN  ...
# 943              2012.0           O                   2008.0  ...
#
#     Constituency over 50% one race  Specific Demographics and Community  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ..                             ...                                  ...
# 939                            NaN                                  NaN
# 940                            NaN                                  NaN
# 941                            NaN                                  NaN
# 942                            NaN                                  NaN
# 943                            NaN                                  NaN
#
#      Organization Leadership  Organization Artists  Closed Date Closed?  \
# 0                        NaN                   NaN          NaN     0.0
# 1                        NaN                   NaN          NaN     0.0
# 2                        NaN                   NaN          NaN     0.0
# 3                        NaN                   NaN          NaN     0.0
# 4                        NaN                   NaN          NaN     NaN
# ..                       ...                   ...          ...     ...
# 939                      NaN                   NaN          NaN     0.0
# 940                      NaN                   NaN          NaN     0.0
# 941                      NaN                   NaN          NaN     0.0
# 942                      NaN                   NaN          NaN     0.0
# 943                      NaN                   NaN          NaN     0.0
#
#                                            Address  \
# 0                                  1312 E Union St
# 1              5817 SW Stevens St Seattle WA 98116
# 2         1107 East Denny Way #A2 Seattle WA 98122
# 3               1115 East Pike St Seattle WA 98122
# 4                                              NaN
# ..                                             ...
# 939     7720 Greenwood Ave N #101 Seattle WA 98103
# 940          2043 Eastlake Ave E Seattle, WA 98102
# 941  5840 Airport Way S Suite 212 Seattle WA 98108
# 942                               Seattle WA 98195
# 943                   440 5th Ave. N Seattle 98109
#
#                        Location   Latitude   Longitude
# 0       (47.612905, -122.31477)  47.612905 -122.314770
# 1      (47.577271, -122.407364)  47.577271 -122.407364
# 2      (47.618587, -122.317818)  47.618587 -122.317818
# 3    (47.6139358, -122.3174302)  47.613936 -122.317430
# 4                           NaN        NaN         NaN
# ..                          ...        ...         ...
# 939     (47.68528, -122.354912)  47.685280 -122.354912
# 940     (47.63803, -122.325924)  47.638030 -122.325924
# 941    (47.550962, -122.318612)  47.550962 -122.318612
# 942    (47.657048, -122.305271)  47.657048 -122.305271
# 943     (47.622541, -122.34748)  47.622541 -122.347480
#
# [944 rows x 37 columns]

# %% [markdown]
# #### Step 2 : drop unusuable rows
#
# - first, using the pandas dropna() method, remove from the culturalspaces data frame any rows which have null in either the Longitude or Latitude columns
# - next, drop rows of culturalspaces which were closed prior to the first date in our cycle hire data (Oct 2014) using any pandas filter approach
# - reset the index of your culturalspaces data frame after dropping rows
#
#
# https://www.geeksforgeeks.org/ways-to-filter-pandas-dataframe-by-column-values/

# %%
df = df.dropna(axis=0, subset=['Latitude', 'Longitude'])

# %%
df[df['Closed?'] ==1.0]
# Out:
#                                                   Name           Phone  \
# 26                                        Capitol Club             NaN
# 48                                  Bop Street Records             NaN
# 82                                  Heartland (CLOSED)             NaN
# 120               Washington Ensemble Theatre (CLOSED)  (206) 325-5105
# 174                                  Theater Schmeater  (206) 324-5801
# 182                          Barnes & Noble - Downtown             NaN
# 190                          Kind Hand Studio (CLOSED)  (206) 618-1447
# 207                                Landmark Guild 45th             NaN
# 262        Room 104 Gallery (CLOSED) in Tashiro Kaplan             NaN
# 276                                    Teatro ZinZanni  (206) 802-0015
# 283                                        Bell & Reed             NaN
# 297                           Macha Monkey Productions             NaN
# 342                        Fetherston Gallery (CLOSED)             NaN
# 346                           Eclectic Theater Company  (206) 679-3271
# 353                  Patricia Cameron Gallery (CLOSED)             NaN
# 372                                     Seattle Weekly             NaN
# 377                                     Comics Dungeon  (206) 545-8373
# 392                       Electric Tea Garden (CLOSED)             NaN
# 422                      Landmark Seven Gables Theatre             NaN
# 494  New Orleans Creole Restaurant + Jazz Music (CL...             NaN
# 526                            Massive Monkees Studios             NaN
# 547      The Josephine and Friends of NW 65th (CLOSED)  (206) 543-0065
# 583                         Blindfold Gallery (CLOSED)             NaN
# 592                                     Studio Current             NaN
# 593                     The Studio of Awesome (CLOSED)             NaN
# 614                          Ltd. Art Gallery (CLOSED)  (206) 457-2970
# 627                                             Re-bar             NaN
# 630                                    The Big Picture  (206) 256-0566
# 673  University of Washington Physics Astronomy Rea...             NaN
# 681                           Art/Not Terminal Gallery  (206) 233-0680
# 726                                     New Foundation  (206) 512-7247
# 798                       Storefronts Seattle/Shunpike  (206) 905-1026
# 799                   Francine Seders Gallery (CLOSED)             NaN
# 802                          The White Rabbit (CLOSED)             NaN
# 805        Pilchuck Glass School Office (CLOSED/MOVED)             NaN
# 857                                         Hugo House  (206) 322-7030
# 878                       Seattle ArtREsource (CLOSED)  (206) 838-2695
# 917                      Harvard Exit Theatre (CLOSED)             NaN
# 919                             Mind Unwind Foundation  (206) 829-9128
# 937                                   New City Theater  (206) 271-4430
#
#                                            URL  Square Feet Total  \
# 26                                         NaN                NaN
# 48                                         NaN                NaN
# 82                                         NaN                NaN
# 120                 www.washingtonensemble.org              800.0
# 174                          www.schmeater.org             3000.0
# 182                                        NaN                NaN
# 190                         www.khspottery.com              158.0
# 207                                        NaN                NaN
# 262                                        NaN                NaN
# 276                   www.zinzanni.com/seattle            28000.0
# 283                                        NaN                NaN
# 297                                        NaN                NaN
# 342                                        NaN                NaN
# 346             www.eclectictheatercompany.org              900.0
# 353                                        NaN                NaN
# 372                                        NaN                NaN
# 377                      www.ComicsDungeon.com             1600.0
# 392                                        NaN                NaN
# 422                                        NaN                NaN
# 494                                        NaN                NaN
# 526                     www.massivemonkees.com             2200.0
# 547  www.josephinebaker-bonaparte.blogspot.com                NaN
# 583                                        NaN                NaN
# 592                                        NaN                NaN
# 593                                        NaN                NaN
# 614                      www.ltdartgallery.com             1100.0
# 627                                        NaN                NaN
# 630                      www.thebigpicture.net             4400.0
# 673                                        NaN                NaN
# 681                         www.antgallery.org             3280.0
# 726                          www.thenewest.org             1800.0
# 798                           www.shunpike.org            26600.0
# 799                                        NaN                NaN
# 802                                        NaN                NaN
# 805                                        NaN                NaN
# 857                          www.hugohouse.org            11000.0
# 878                 www.seattleartresource.com             2500.0
# 917                                        NaN                NaN
# 919                         www.mindunwind.org             2000.0
# 937                     www.newcitytheater.org             1950.0
#
#                          Neighborhood Organization Type  \
# 26                                NaN               NaN
# 48                                NaN               NaN
# 82                                NaN               NaN
# 120                      Capitol Hill                 Y
# 174                      Capitol Hill                 Y
# 182                          Downtown               NaN
# 190                           Ballard                 N
# 207                               NaN               NaN
# 262                               NaN               NaN
# 276                            Uptown                 Y
# 283                    Pioneer Square               NaN
# 297                               NaN               NaN
# 342                               NaN               NaN
# 346                      Capitol Hill                 Y
# 353                               NaN               NaN
# 372                    Pioneer Square               NaN
# 377                       Wallingford                 N
# 392                               NaN               NaN
# 422                               NaN               NaN
# 494                               NaN               NaN
# 526  Chinatown International District                 N
# 547                           Ballard                 Y
# 583                               NaN               NaN
# 592                      Capitol Hill               NaN
# 593                               NaN               NaN
# 614                      Capitol Hill                 N
# 627                               NaN               NaN
# 630                          Belltown                 N
# 673                               NaN               NaN
# 681                  South Lake Union                 Y
# 726                  Central District                 Y
# 798                          Belltown                 Y
# 799                               NaN               NaN
# 802                               NaN               NaN
# 805                               NaN               NaN
# 857                      Capitol Hill                 Y
# 878                    Pioneer Square                 N
# 917                               NaN               NaN
# 919                           Admiral                 Y
# 937                  Central District                 Y
#
#                           Dominant Discipline  Year of Occupation Rent vs Own  \
# 26                                      Music                 NaN         NaN
# 48                                      Music                 NaN         NaN
# 82                                      Music                 NaN         NaN
# 120                               Performance              2003.0           R
# 174                               Performance                 NaN           R
# 182                                  Literary                 NaN         NaN
# 190       Arts/Cultural Training or Education              2012.0           R
# 207                                    Cinema                 NaN         NaN
# 262                                    Visual                 NaN         NaN
# 276                               Performance              2006.0           R
# 283                            Service/Supply                 NaN         NaN
# 297                               Performance                 NaN         NaN
# 342                                    Visual                 NaN         NaN
# 346                               Performance              2006.0           R
# 353                                    Visual                 NaN         NaN
# 372                            Service/Supply                 NaN         NaN
# 377                                    Visual              2012.0           R
# 392                                     Music                 NaN         NaN
# 422                                    Cinema                 NaN         NaN
# 494                                     Music                 NaN         NaN
# 526                               Performance              2013.0           R
# 547                                 Multi-use                 NaN           R
# 583                                    Visual                 NaN         NaN
# 592                                 Multi-use                 NaN         NaN
# 593                                     Music                 NaN         NaN
# 614                                    Visual              2011.0           R
# 627                                     Music                 NaN         NaN
# 630                                    Cinema              1998.0         NaN
# 673                                 Education                 NaN         NaN
# 681                                    Visual              1993.0           R
# 726                                    Visual              2012.0           R
# 798                                 Multi-use              2007.0           R
# 799                                    Visual                 NaN         NaN
# 802                                     Music                 NaN         NaN
# 805  Arts/Cultural Administration or Advocacy                 NaN         NaN
# 857                                  Literary              2004.0           R
# 878                                    Visual              2006.0           O
# 917                                    Cinema                 NaN         NaN
# 919       Arts/Cultural Training or Education              2011.0           R
# 937                               Performance              2008.0           R
#
#      Age of Current Building  ... Constituency over 50% one race  \
# 26                       NaN  ...                            NaN
# 48                       NaN  ...                            NaN
# 82                       NaN  ...                            NaN
# 120                      NaN  ...                            NaN
# 174                   2008.0  ...                            NaN
# 182                      NaN  ...                            NaN
# 190                      NaN  ...                            NaN
# 207                      NaN  ...                            NaN
# 262                      NaN  ...                            NaN
# 276                   2006.0  ...                            NaN
# 283                      NaN  ...                            NaN
# 297                      NaN  ...                            NaN
# 342                      NaN  ...                            NaN
# 346                   1910.0  ...                            NaN
# 353                      NaN  ...                            NaN
# 372                      NaN  ...                            NaN
# 377                   1950.0  ...                            NaN
# 392                      NaN  ...                            NaN
# 422                      NaN  ...                            NaN
# 494                      NaN  ...                            NaN
# 526                   1950.0  ...                            NaN
# 547                   1932.0  ...                            NaN
# 583                      NaN  ...                            NaN
# 592                      NaN  ...                            NaN
# 593                      NaN  ...                            NaN
# 614                   2008.0  ...                            NaN
# 627                      NaN  ...                            NaN
# 630                   1950.0  ...                            NaN
# 673                      NaN  ...                            NaN
# 681                   1920.0  ...                            NaN
# 726                   1919.0  ...                            NaN
# 798                   1889.0  ...                            NaN
# 799                      NaN  ...                            NaN
# 802                      NaN  ...                            NaN
# 805                      NaN  ...                            NaN
# 857                   1900.0  ...                            NaN
# 878                   1905.0  ...                            NaN
# 917                      NaN  ...                            NaN
# 919                   2011.0  ...                            NaN
# 937                   1935.0  ...                            NaN
#
#      Specific Demographics and Community  Organization Leadership  \
# 26                                   NaN                      NaN
# 48                                   NaN                      NaN
# 82                                   NaN                      NaN
# 120                                  NaN                      NaN
# 174                                  NaN                      NaN
# 182                                  NaN                      NaN
# 190                                  NaN                      NaN
# 207                                  NaN                      NaN
# 262                                  NaN                      NaN
# 276                                  NaN                      NaN
# 283                                  NaN                      NaN
# 297                                  NaN                      NaN
# 342                                  NaN                      NaN
# 346                                  NaN                      NaN
# 353                                  NaN                      NaN
# 372                                  NaN                      NaN
# 377                                  NaN                      NaN
# 392                                  NaN                      NaN
# 422                                  NaN                      NaN
# 494                                  NaN                      NaN
# 526                                  NaN                      NaN
# 547                                  NaN                      NaN
# 583                                  NaN                      NaN
# 592                                  NaN                      NaN
# 593                                  NaN                      NaN
# 614                                  NaN                      NaN
# 627                                  NaN                      NaN
# 630                                  NaN                      NaN
# 673                                  NaN                      NaN
# 681                                  NaN                      NaN
# 726                                  NaN                      NaN
# 798                                  NaN                      NaN
# 799                                  NaN                      NaN
# 802                                  NaN                      NaN
# 805                                  NaN                      NaN
# 857                                  NaN                      NaN
# 878                                  NaN                      NaN
# 917                                  NaN                      NaN
# 919                                  NaN                      NaN
# 937                                  NaN                      NaN
#
#      Organization Artists              Closed Date Closed?  \
# 26                    NaN  2013-09-14T00:00:00.000     1.0
# 48                    NaN  2020-06-01T00:00:00.000     1.0
# 82                    NaN                      NaN     1.0
# 120                   NaN  2014-07-31T00:00:00.000     1.0
# 174                   NaN  2013-11-01T00:00:00.000     1.0
# 182                   NaN                      NaN     1.0
# 190                   NaN  2013-12-01T00:00:00.000     1.0
# 207                   NaN  2017-06-01T00:00:00.000     1.0
# 262                   NaN  2014-08-01T00:00:00.000     1.0
# 276                   NaN  2017-03-05T00:00:00.000     1.0
# 283                   NaN                      NaN     1.0
# 297                   NaN  2017-05-31T00:00:00.000     1.0
# 342                   NaN  2016-03-14T00:00:00.000     1.0
# 346                   NaN  2017-10-31T00:00:00.000     1.0
# 353                   NaN  2014-06-30T00:00:00.000     1.0
# 372                   NaN  2017-10-25T00:00:00.000     1.0
# 377                   NaN  2020-07-01T00:00:00.000     1.0
# 392                   NaN  2014-01-01T00:00:00.000     1.0
# 422                   NaN  2017-06-01T00:00:00.000     1.0
# 494                   NaN  2014-08-01T00:00:00.000     1.0
# 526                   NaN  2020-12-20T00:00:00.000     1.0
# 547                   NaN  2015-02-01T00:00:00.000     1.0
# 583                   NaN  2014-12-11T00:00:00.000     1.0
# 592                   NaN  2016-09-30T00:00:00.000     1.0
# 593                   NaN  2016-11-13T00:00:00.000     1.0
# 614                   NaN  2015-03-01T00:00:00.000     1.0
# 627                   NaN  2020-06-01T00:00:00.000     1.0
# 630                   NaN  2020-05-01T00:00:00.000     1.0
# 673                   NaN                      NaN     1.0
# 681                   NaN  2016-05-31T00:00:00.000     1.0
# 726                   NaN  2016-05-01T00:00:00.000     1.0
# 798                   NaN                      NaN     1.0
# 799                   NaN  2013-12-31T00:00:00.000     1.0
# 802                   NaN  2016-12-13T00:00:00.000     1.0
# 805                   NaN  2016-10-14T00:00:00.000     1.0
# 857                   NaN  2016-05-15T00:00:00.000     1.0
# 878                   NaN  2015-03-28T00:00:00.000     1.0
# 917                   NaN  2015-01-31T00:00:00.000     1.0
# 919                   NaN                      NaN     1.0
# 937                   NaN                      NaN     1.0
#
#                                              Address  \
# 26                    414 E Pine St Seattle WA 98122
# 48                2220 NW Market St Seattle WA 98107
# 82            5306 Roosevelt Way NE Seattle WA 98105
# 120                  608 19th Ave E Seattle WA 98112
# 174                 1500 Summit Ave Seattle WA 98122
# 182           600 Pine St Suite 107 Seattle WA 98101
# 190             4775 Ballard Ave NW Seattle WA 98107
# 207                  2115 N 45th St Seattle WA 98103
# 262       306 S. Washington St #104 Seattle WA 98104
# 276                   222 Mercer St Seattle WA 98109
# 283  15 Prefontaine Pl. S Suite 510 Seattle WA 98104
# 297               2222 2nd Ave #200 Seattle WA 98121
# 342                 5701 6th Ave S, Seattle WA 98108
# 346                   1214 10th Ave Seattle WA 98122
# 353                234 Dexter Ave N Seattle WA 98109
# 372      307 3rd Ave S Second Floor Seattle WA 98104
# 377                  319 NE 45th St Seattle WA 98105
# 392                  1402 E Pike St Seattle WA 98122
# 422                  911 NE 50th St Seattle WA 98105
# 494                 114 First Ave S Seattle WA 98104
# 526                   664 S King St Seattle WA 98104
# 547                  608 NW 65th St Seattle WA 98117
# 583                1718 E Olive Way Seattle WA 98102
# 592                1417 10th Ave #C Seattle WA 98122
# 593          101 N 85th Street #201 Seattle WA 98103
# 614                   307 E Pike St Seattle WA 98122
# 627                  1114 Howell St Seattle WA 98101
# 630                    2505 1st Ave Seattle WA 98121
# 673                3910 15th Ave NE Seattle WA 98105
# 681               2045 Westlake Ave Seattle WA 98121
# 726                     312 2nd Ave South Seattle WA
# 798              2324 1st Ave # 112 Seattle WA 98121
# 799            6701 Greenwood Ave N Seattle WA 98103
# 802                   513 N 36th St Seattle WA 98103
# 805                  430 Yale Ave N Seattle WA 98109
# 857                   1634 11th Ave Seattle WA 98122
# 878                625 1st Ave #200 Seattle WA 98104
# 917                    807 E Roy St Seattle WA 98102
# 919         2206A California Ave SW Seattle WA 98116
# 937                   1404 18th Ave Seattle WA 98122
#
#                         Location   Latitude   Longitude
# 26    (47.6153941, -122.3260485)  47.615394 -122.326048
# 48       (47.66909, -122.385796)  47.669090 -122.385796
# 82   (47.66739015, -122.3170984)  47.667390 -122.317098
# 120    (47.6247086, -122.307185)  47.624709 -122.307185
# 174       (47.61344, -122.34325)  47.613440 -122.343250
# 182  (47.61287415, -122.3352762)  47.612874 -122.335276
# 190   (47.6642404, -122.3810653)  47.664240 -122.381065
# 207  (47.66112015, -122.3330128)  47.661120 -122.333013
# 262   (47.6010201, -122.3298371)  47.601020 -122.329837
# 276   (47.6249259, -122.3518443)  47.624926 -122.351844
# 283     (47.601719, -122.330269)  47.601719 -122.330269
# 297     (47.613483, -122.344756)  47.613483 -122.344756
# 342   (47.5514664, -122.3283134)  47.551466 -122.328313
# 346   (47.6126561, -122.3191571)  47.612656 -122.319157
# 353   (47.6207093, -122.3420916)  47.620709 -122.342092
# 372      (47.599701, -122.33065)  47.599701 -122.330650
# 377       (47.661356, -122.3248)  47.661356 -122.324800
# 392      (47.6143, -122.3139168)  47.614300 -122.313917
# 422   (47.6647555, -122.3177085)  47.664755 -122.317708
# 494   (47.5965162, -122.3341906)  47.596516 -122.334191
# 526     (47.598602, -122.324135)  47.598602 -122.324135
# 547   (47.6762165, -122.3638347)  47.676217 -122.363835
# 583   (47.6200267, -122.3227112)  47.620027 -122.322711
# 592     (47.613223, -122.319412)  47.613223 -122.319412
# 593     (47.69038, -122.3577075)  47.690380 -122.357708
# 614   (47.6138928, -122.3271174)  47.613893 -122.327117
# 627   (47.6167076, -122.3310756)  47.616708 -122.331076
# 630   (47.6146778, -122.3492477)  47.614678 -122.349248
# 673      (47.65408, -122.312135)  47.654080 -122.312135
# 681    (47.6158592, -122.338453)  47.615859 -122.338453
# 726     (47.599537, -122.331177)  47.599537 -122.331177
# 798   (47.6139909, -122.3472372)  47.613991 -122.347237
# 799   (47.6779185, -122.3556352)  47.677918 -122.355635
# 802   (47.6513564, -122.3515985)  47.651356 -122.351598
# 805   (47.6228012, -122.3302142)  47.622801 -122.330214
# 857   (47.6162473, -122.3178798)  47.616247 -122.317880
# 878   (47.6024431, -122.3344096)  47.602443 -122.334410
# 917   (47.6250082, -122.3215822)  47.625008 -122.321582
# 919     (47.583717, -122.386024)  47.583717 -122.386024
# 937   (47.6131012, -122.3086934)  47.613101 -122.308693
#
# [40 rows x 37 columns]

# %%
df['Closed Date']=pd.to_datetime(df['Closed Date'])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8288\2865966520.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Closed Date']=pd.to_datetime(df['Closed Date'])

# %% [markdown]
# #### Step 3 : create a data frame from the cycle hire station data to get the ranges of longitude and latitude
#
# - use pandas read_csv to create a second data frame from seattle_cycles_station.csv file
# - use max() and min() to identify the range of longitude and latitude values in the cycle station data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 912 entries, 0 to 943
# Data columns (total 37 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Name                                                         912 non-null    object
#  1   Phone                                                        460 non-null    object
#  2   URL                                                          463 non-null    object
#  3   Square Feet Total                                            447 non-null    float64
#  4   Neighborhood                                                 496 non-null    object
#  5   Organization Type                                            484 non-null    object
#  6   Dominant Discipline                                          873 non-null    object
#  7   Year of Occupation                                           458 non-null    float64
#  8   Rent vs Own                                                  462 non-null    object
#  9   Age of Current Building                                      432 non-null    float64
#  10  Length of Lease (Date)                                       352 non-null    object
#  11   Year Organization Founded                                   456 non-null    float64
#  12  Number of Past Facilities                                    450 non-null    float64
#  13  Stages and Theaters                                          445 non-null    float64
#  14  Stage & Theater Seats                                        385 non-null    float64
#  15  Gallery Space                                                449 non-null    object
#  16  Gallery Square Feet                                          357 non-null    float64
#  17  ADA Compliant                                                434 non-null    object
#  18  Available Parking                                            369 non-null    float64
#  19  Street Presence                                              455 non-null    object
#  20  Rental Space                                                 451 non-null    object
#  21  Alcohol Sales                                                459 non-null    object
#  22  Organization Mission                                         40 non-null     object
#  23  Funded by A&C                                                458 non-null    object
#  24  Funded by 4Culture                                           25 non-null     object
#  25  Stability Index (5=very stable, 1=very uncertain)            459 non-null    float64
#  26  Control Index (5=very in control, 1 = very out of control)   40 non-null     float64
#  27  Constituency over 50% one race                               38 non-null     object
#  28  Specific Demographics and Community                          38 non-null     object
#  29  Organization Leadership                                      16 non-null     object
#  30  Organization Artists                                         15 non-null     object
#  31  Closed Date                                                  33 non-null     datetime64[ns]
#  32  Closed?                                                      835 non-null    float64
#  33  Address                                                      909 non-null    object
#  34  Location                                                     912 non-null    object
#  35  Latitude                                                     912 non-null    float64
#  36  Longitude                                                    912 non-null    float64
# dtypes: datetime64[ns](1), float64(14), object(22)
# memory usage: 270.8+ KB

# %%
df[df['Closed?'] ==1.0]
# Out:
#                                                   Name           Phone  \
# 26                                        Capitol Club             NaN
# 48                                  Bop Street Records             NaN
# 82                                  Heartland (CLOSED)             NaN
# 120               Washington Ensemble Theatre (CLOSED)  (206) 325-5105
# 174                                  Theater Schmeater  (206) 324-5801
# 182                          Barnes & Noble - Downtown             NaN
# 190                          Kind Hand Studio (CLOSED)  (206) 618-1447
# 207                                Landmark Guild 45th             NaN
# 262        Room 104 Gallery (CLOSED) in Tashiro Kaplan             NaN
# 276                                    Teatro ZinZanni  (206) 802-0015
# 283                                        Bell & Reed             NaN
# 297                           Macha Monkey Productions             NaN
# 342                        Fetherston Gallery (CLOSED)             NaN
# 346                           Eclectic Theater Company  (206) 679-3271
# 353                  Patricia Cameron Gallery (CLOSED)             NaN
# 372                                     Seattle Weekly             NaN
# 377                                     Comics Dungeon  (206) 545-8373
# 392                       Electric Tea Garden (CLOSED)             NaN
# 422                      Landmark Seven Gables Theatre             NaN
# 494  New Orleans Creole Restaurant + Jazz Music (CL...             NaN
# 526                            Massive Monkees Studios             NaN
# 547      The Josephine and Friends of NW 65th (CLOSED)  (206) 543-0065
# 583                         Blindfold Gallery (CLOSED)             NaN
# 592                                     Studio Current             NaN
# 593                     The Studio of Awesome (CLOSED)             NaN
# 614                          Ltd. Art Gallery (CLOSED)  (206) 457-2970
# 627                                             Re-bar             NaN
# 630                                    The Big Picture  (206) 256-0566
# 673  University of Washington Physics Astronomy Rea...             NaN
# 681                           Art/Not Terminal Gallery  (206) 233-0680
# 726                                     New Foundation  (206) 512-7247
# 798                       Storefronts Seattle/Shunpike  (206) 905-1026
# 799                   Francine Seders Gallery (CLOSED)             NaN
# 802                          The White Rabbit (CLOSED)             NaN
# 805        Pilchuck Glass School Office (CLOSED/MOVED)             NaN
# 857                                         Hugo House  (206) 322-7030
# 878                       Seattle ArtREsource (CLOSED)  (206) 838-2695
# 917                      Harvard Exit Theatre (CLOSED)             NaN
# 919                             Mind Unwind Foundation  (206) 829-9128
# 937                                   New City Theater  (206) 271-4430
#
#                                            URL  Square Feet Total  \
# 26                                         NaN                NaN
# 48                                         NaN                NaN
# 82                                         NaN                NaN
# 120                 www.washingtonensemble.org              800.0
# 174                          www.schmeater.org             3000.0
# 182                                        NaN                NaN
# 190                         www.khspottery.com              158.0
# 207                                        NaN                NaN
# 262                                        NaN                NaN
# 276                   www.zinzanni.com/seattle            28000.0
# 283                                        NaN                NaN
# 297                                        NaN                NaN
# 342                                        NaN                NaN
# 346             www.eclectictheatercompany.org              900.0
# 353                                        NaN                NaN
# 372                                        NaN                NaN
# 377                      www.ComicsDungeon.com             1600.0
# 392                                        NaN                NaN
# 422                                        NaN                NaN
# 494                                        NaN                NaN
# 526                     www.massivemonkees.com             2200.0
# 547  www.josephinebaker-bonaparte.blogspot.com                NaN
# 583                                        NaN                NaN
# 592                                        NaN                NaN
# 593                                        NaN                NaN
# 614                      www.ltdartgallery.com             1100.0
# 627                                        NaN                NaN
# 630                      www.thebigpicture.net             4400.0
# 673                                        NaN                NaN
# 681                         www.antgallery.org             3280.0
# 726                          www.thenewest.org             1800.0
# 798                           www.shunpike.org            26600.0
# 799                                        NaN                NaN
# 802                                        NaN                NaN
# 805                                        NaN                NaN
# 857                          www.hugohouse.org            11000.0
# 878                 www.seattleartresource.com             2500.0
# 917                                        NaN                NaN
# 919                         www.mindunwind.org             2000.0
# 937                     www.newcitytheater.org             1950.0
#
#                          Neighborhood Organization Type  \
# 26                                NaN               NaN
# 48                                NaN               NaN
# 82                                NaN               NaN
# 120                      Capitol Hill                 Y
# 174                      Capitol Hill                 Y
# 182                          Downtown               NaN
# 190                           Ballard                 N
# 207                               NaN               NaN
# 262                               NaN               NaN
# 276                            Uptown                 Y
# 283                    Pioneer Square               NaN
# 297                               NaN               NaN
# 342                               NaN               NaN
# 346                      Capitol Hill                 Y
# 353                               NaN               NaN
# 372                    Pioneer Square               NaN
# 377                       Wallingford                 N
# 392                               NaN               NaN
# 422                               NaN               NaN
# 494                               NaN               NaN
# 526  Chinatown International District                 N
# 547                           Ballard                 Y
# 583                               NaN               NaN
# 592                      Capitol Hill               NaN
# 593                               NaN               NaN
# 614                      Capitol Hill                 N
# 627                               NaN               NaN
# 630                          Belltown                 N
# 673                               NaN               NaN
# 681                  South Lake Union                 Y
# 726                  Central District                 Y
# 798                          Belltown                 Y
# 799                               NaN               NaN
# 802                               NaN               NaN
# 805                               NaN               NaN
# 857                      Capitol Hill                 Y
# 878                    Pioneer Square                 N
# 917                               NaN               NaN
# 919                           Admiral                 Y
# 937                  Central District                 Y
#
#                           Dominant Discipline  Year of Occupation Rent vs Own  \
# 26                                      Music                 NaN         NaN
# 48                                      Music                 NaN         NaN
# 82                                      Music                 NaN         NaN
# 120                               Performance              2003.0           R
# 174                               Performance                 NaN           R
# 182                                  Literary                 NaN         NaN
# 190       Arts/Cultural Training or Education              2012.0           R
# 207                                    Cinema                 NaN         NaN
# 262                                    Visual                 NaN         NaN
# 276                               Performance              2006.0           R
# 283                            Service/Supply                 NaN         NaN
# 297                               Performance                 NaN         NaN
# 342                                    Visual                 NaN         NaN
# 346                               Performance              2006.0           R
# 353                                    Visual                 NaN         NaN
# 372                            Service/Supply                 NaN         NaN
# 377                                    Visual              2012.0           R
# 392                                     Music                 NaN         NaN
# 422                                    Cinema                 NaN         NaN
# 494                                     Music                 NaN         NaN
# 526                               Performance              2013.0           R
# 547                                 Multi-use                 NaN           R
# 583                                    Visual                 NaN         NaN
# 592                                 Multi-use                 NaN         NaN
# 593                                     Music                 NaN         NaN
# 614                                    Visual              2011.0           R
# 627                                     Music                 NaN         NaN
# 630                                    Cinema              1998.0         NaN
# 673                                 Education                 NaN         NaN
# 681                                    Visual              1993.0           R
# 726                                    Visual              2012.0           R
# 798                                 Multi-use              2007.0           R
# 799                                    Visual                 NaN         NaN
# 802                                     Music                 NaN         NaN
# 805  Arts/Cultural Administration or Advocacy                 NaN         NaN
# 857                                  Literary              2004.0           R
# 878                                    Visual              2006.0           O
# 917                                    Cinema                 NaN         NaN
# 919       Arts/Cultural Training or Education              2011.0           R
# 937                               Performance              2008.0           R
#
#      Age of Current Building  ... Constituency over 50% one race  \
# 26                       NaN  ...                            NaN
# 48                       NaN  ...                            NaN
# 82                       NaN  ...                            NaN
# 120                      NaN  ...                            NaN
# 174                   2008.0  ...                            NaN
# 182                      NaN  ...                            NaN
# 190                      NaN  ...                            NaN
# 207                      NaN  ...                            NaN
# 262                      NaN  ...                            NaN
# 276                   2006.0  ...                            NaN
# 283                      NaN  ...                            NaN
# 297                      NaN  ...                            NaN
# 342                      NaN  ...                            NaN
# 346                   1910.0  ...                            NaN
# 353                      NaN  ...                            NaN
# 372                      NaN  ...                            NaN
# 377                   1950.0  ...                            NaN
# 392                      NaN  ...                            NaN
# 422                      NaN  ...                            NaN
# 494                      NaN  ...                            NaN
# 526                   1950.0  ...                            NaN
# 547                   1932.0  ...                            NaN
# 583                      NaN  ...                            NaN
# 592                      NaN  ...                            NaN
# 593                      NaN  ...                            NaN
# 614                   2008.0  ...                            NaN
# 627                      NaN  ...                            NaN
# 630                   1950.0  ...                            NaN
# 673                      NaN  ...                            NaN
# 681                   1920.0  ...                            NaN
# 726                   1919.0  ...                            NaN
# 798                   1889.0  ...                            NaN
# 799                      NaN  ...                            NaN
# 802                      NaN  ...                            NaN
# 805                      NaN  ...                            NaN
# 857                   1900.0  ...                            NaN
# 878                   1905.0  ...                            NaN
# 917                      NaN  ...                            NaN
# 919                   2011.0  ...                            NaN
# 937                   1935.0  ...                            NaN
#
#      Specific Demographics and Community  Organization Leadership  \
# 26                                   NaN                      NaN
# 48                                   NaN                      NaN
# 82                                   NaN                      NaN
# 120                                  NaN                      NaN
# 174                                  NaN                      NaN
# 182                                  NaN                      NaN
# 190                                  NaN                      NaN
# 207                                  NaN                      NaN
# 262                                  NaN                      NaN
# 276                                  NaN                      NaN
# 283                                  NaN                      NaN
# 297                                  NaN                      NaN
# 342                                  NaN                      NaN
# 346                                  NaN                      NaN
# 353                                  NaN                      NaN
# 372                                  NaN                      NaN
# 377                                  NaN                      NaN
# 392                                  NaN                      NaN
# 422                                  NaN                      NaN
# 494                                  NaN                      NaN
# 526                                  NaN                      NaN
# 547                                  NaN                      NaN
# 583                                  NaN                      NaN
# 592                                  NaN                      NaN
# 593                                  NaN                      NaN
# 614                                  NaN                      NaN
# 627                                  NaN                      NaN
# 630                                  NaN                      NaN
# 673                                  NaN                      NaN
# 681                                  NaN                      NaN
# 726                                  NaN                      NaN
# 798                                  NaN                      NaN
# 799                                  NaN                      NaN
# 802                                  NaN                      NaN
# 805                                  NaN                      NaN
# 857                                  NaN                      NaN
# 878                                  NaN                      NaN
# 917                                  NaN                      NaN
# 919                                  NaN                      NaN
# 937                                  NaN                      NaN
#
#      Organization Artists  Closed Date Closed?  \
# 26                    NaN   2013-09-14     1.0
# 48                    NaN   2020-06-01     1.0
# 82                    NaN          NaT     1.0
# 120                   NaN   2014-07-31     1.0
# 174                   NaN   2013-11-01     1.0
# 182                   NaN          NaT     1.0
# 190                   NaN   2013-12-01     1.0
# 207                   NaN   2017-06-01     1.0
# 262                   NaN   2014-08-01     1.0
# 276                   NaN   2017-03-05     1.0
# 283                   NaN          NaT     1.0
# 297                   NaN   2017-05-31     1.0
# 342                   NaN   2016-03-14     1.0
# 346                   NaN   2017-10-31     1.0
# 353                   NaN   2014-06-30     1.0
# 372                   NaN   2017-10-25     1.0
# 377                   NaN   2020-07-01     1.0
# 392                   NaN   2014-01-01     1.0
# 422                   NaN   2017-06-01     1.0
# 494                   NaN   2014-08-01     1.0
# 526                   NaN   2020-12-20     1.0
# 547                   NaN   2015-02-01     1.0
# 583                   NaN   2014-12-11     1.0
# 592                   NaN   2016-09-30     1.0
# 593                   NaN   2016-11-13     1.0
# 614                   NaN   2015-03-01     1.0
# 627                   NaN   2020-06-01     1.0
# 630                   NaN   2020-05-01     1.0
# 673                   NaN          NaT     1.0
# 681                   NaN   2016-05-31     1.0
# 726                   NaN   2016-05-01     1.0
# 798                   NaN          NaT     1.0
# 799                   NaN   2013-12-31     1.0
# 802                   NaN   2016-12-13     1.0
# 805                   NaN   2016-10-14     1.0
# 857                   NaN   2016-05-15     1.0
# 878                   NaN   2015-03-28     1.0
# 917                   NaN   2015-01-31     1.0
# 919                   NaN          NaT     1.0
# 937                   NaN          NaT     1.0
#
#                                              Address  \
# 26                    414 E Pine St Seattle WA 98122
# 48                2220 NW Market St Seattle WA 98107
# 82            5306 Roosevelt Way NE Seattle WA 98105
# 120                  608 19th Ave E Seattle WA 98112
# 174                 1500 Summit Ave Seattle WA 98122
# 182           600 Pine St Suite 107 Seattle WA 98101
# 190             4775 Ballard Ave NW Seattle WA 98107
# 207                  2115 N 45th St Seattle WA 98103
# 262       306 S. Washington St #104 Seattle WA 98104
# 276                   222 Mercer St Seattle WA 98109
# 283  15 Prefontaine Pl. S Suite 510 Seattle WA 98104
# 297               2222 2nd Ave #200 Seattle WA 98121
# 342                 5701 6th Ave S, Seattle WA 98108
# 346                   1214 10th Ave Seattle WA 98122
# 353                234 Dexter Ave N Seattle WA 98109
# 372      307 3rd Ave S Second Floor Seattle WA 98104
# 377                  319 NE 45th St Seattle WA 98105
# 392                  1402 E Pike St Seattle WA 98122
# 422                  911 NE 50th St Seattle WA 98105
# 494                 114 First Ave S Seattle WA 98104
# 526                   664 S King St Seattle WA 98104
# 547                  608 NW 65th St Seattle WA 98117
# 583                1718 E Olive Way Seattle WA 98102
# 592                1417 10th Ave #C Seattle WA 98122
# 593          101 N 85th Street #201 Seattle WA 98103
# 614                   307 E Pike St Seattle WA 98122
# 627                  1114 Howell St Seattle WA 98101
# 630                    2505 1st Ave Seattle WA 98121
# 673                3910 15th Ave NE Seattle WA 98105
# 681               2045 Westlake Ave Seattle WA 98121
# 726                     312 2nd Ave South Seattle WA
# 798              2324 1st Ave # 112 Seattle WA 98121
# 799            6701 Greenwood Ave N Seattle WA 98103
# 802                   513 N 36th St Seattle WA 98103
# 805                  430 Yale Ave N Seattle WA 98109
# 857                   1634 11th Ave Seattle WA 98122
# 878                625 1st Ave #200 Seattle WA 98104
# 917                    807 E Roy St Seattle WA 98102
# 919         2206A California Ave SW Seattle WA 98116
# 937                   1404 18th Ave Seattle WA 98122
#
#                         Location   Latitude   Longitude
# 26    (47.6153941, -122.3260485)  47.615394 -122.326048
# 48       (47.66909, -122.385796)  47.669090 -122.385796
# 82   (47.66739015, -122.3170984)  47.667390 -122.317098
# 120    (47.6247086, -122.307185)  47.624709 -122.307185
# 174       (47.61344, -122.34325)  47.613440 -122.343250
# 182  (47.61287415, -122.3352762)  47.612874 -122.335276
# 190   (47.6642404, -122.3810653)  47.664240 -122.381065
# 207  (47.66112015, -122.3330128)  47.661120 -122.333013
# 262   (47.6010201, -122.3298371)  47.601020 -122.329837
# 276   (47.6249259, -122.3518443)  47.624926 -122.351844
# 283     (47.601719, -122.330269)  47.601719 -122.330269
# 297     (47.613483, -122.344756)  47.613483 -122.344756
# 342   (47.5514664, -122.3283134)  47.551466 -122.328313
# 346   (47.6126561, -122.3191571)  47.612656 -122.319157
# 353   (47.6207093, -122.3420916)  47.620709 -122.342092
# 372      (47.599701, -122.33065)  47.599701 -122.330650
# 377       (47.661356, -122.3248)  47.661356 -122.324800
# 392      (47.6143, -122.3139168)  47.614300 -122.313917
# 422   (47.6647555, -122.3177085)  47.664755 -122.317708
# 494   (47.5965162, -122.3341906)  47.596516 -122.334191
# 526     (47.598602, -122.324135)  47.598602 -122.324135
# 547   (47.6762165, -122.3638347)  47.676217 -122.363835
# 583   (47.6200267, -122.3227112)  47.620027 -122.322711
# 592     (47.613223, -122.319412)  47.613223 -122.319412
# 593     (47.69038, -122.3577075)  47.690380 -122.357708
# 614   (47.6138928, -122.3271174)  47.613893 -122.327117
# 627   (47.6167076, -122.3310756)  47.616708 -122.331076
# 630   (47.6146778, -122.3492477)  47.614678 -122.349248
# 673      (47.65408, -122.312135)  47.654080 -122.312135
# 681    (47.6158592, -122.338453)  47.615859 -122.338453
# 726     (47.599537, -122.331177)  47.599537 -122.331177
# 798   (47.6139909, -122.3472372)  47.613991 -122.347237
# 799   (47.6779185, -122.3556352)  47.677918 -122.355635
# 802   (47.6513564, -122.3515985)  47.651356 -122.351598
# 805   (47.6228012, -122.3302142)  47.622801 -122.330214
# 857   (47.6162473, -122.3178798)  47.616247 -122.317880
# 878   (47.6024431, -122.3344096)  47.602443 -122.334410
# 917   (47.6250082, -122.3215822)  47.625008 -122.321582
# 919     (47.583717, -122.386024)  47.583717 -122.386024
# 937   (47.6131012, -122.3086934)  47.613101 -122.308693
#
# [40 rows x 37 columns]

# %%
closed_places = df[df['Closed Date'] < '2014-09-30'].index

# %%
df.drop(closed_places, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8288\2371982523.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(closed_places, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 903 entries, 0 to 943
# Data columns (total 37 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Name                                                         903 non-null    object
#  1   Phone                                                        457 non-null    object
#  2   URL                                                          460 non-null    object
#  3   Square Feet Total                                            444 non-null    float64
#  4   Neighborhood                                                 493 non-null    object
#  5   Organization Type                                            481 non-null    object
#  6   Dominant Discipline                                          864 non-null    object
#  7   Year of Occupation                                           456 non-null    float64
#  8   Rent vs Own                                                  459 non-null    object
#  9   Age of Current Building                                      431 non-null    float64
#  10  Length of Lease (Date)                                       349 non-null    object
#  11   Year Organization Founded                                   453 non-null    float64
#  12  Number of Past Facilities                                    447 non-null    float64
#  13  Stages and Theaters                                          442 non-null    float64
#  14  Stage & Theater Seats                                        382 non-null    float64
#  15  Gallery Space                                                446 non-null    object
#  16  Gallery Square Feet                                          356 non-null    float64
#  17  ADA Compliant                                                432 non-null    object
#  18  Available Parking                                            366 non-null    float64
#  19  Street Presence                                              453 non-null    object
#  20  Rental Space                                                 449 non-null    object
#  21  Alcohol Sales                                                457 non-null    object
#  22  Organization Mission                                         40 non-null     object
#  23  Funded by A&C                                                455 non-null    object
#  24  Funded by 4Culture                                           25 non-null     object
#  25  Stability Index (5=very stable, 1=very uncertain)            456 non-null    float64
#  26  Control Index (5=very in control, 1 = very out of control)   40 non-null     float64
#  27  Constituency over 50% one race                               38 non-null     object
#  28  Specific Demographics and Community                          38 non-null     object
#  29  Organization Leadership                                      16 non-null     object
#  30  Organization Artists                                         15 non-null     object
#  31  Closed Date                                                  24 non-null     datetime64[ns]
#  32  Closed?                                                      826 non-null    float64
#  33  Address                                                      900 non-null    object
#  34  Location                                                     903 non-null    object
#  35  Latitude                                                     903 non-null    float64
#  36  Longitude                                                    903 non-null    float64
# dtypes: datetime64[ns](1), float64(14), object(22)
# memory usage: 268.1+ KB

# %% [markdown]
# #### step 4: drop rows which are outside of the cycle hire data range
#
# - use any pandas filter method to retain rows in the culturalspaces dataframe which are inside the relevant long/lat range of the cycle hire stations
# - reset the index of your culturalspaces dataframe after dropping rows

# %% [markdown]
# #### step 5: simplify and fill gaps in location using python text analysis methods
#
# this data is quite text heavy, so you will now use methods you encountered in topic 8 to process the data
#
# - simplify the cultural space category by using any  pandas string method to keep the first word of the Dominant Discipline column, creating a new column 'purpose'
# (eg 'Arts/Cultural Training or Education' will become simply 'Arts' in the purpose column )
#
# - using a similar method, simplify the neighbourhood column, creating a neighbourhood_clean column, and amend any typos you see
# (eg 'University District and Laurelhurst/Sand Point' will be classed as 'University District')
#
# - fill in any gaps in the neighbourhood_clean column as 'unknown neighbourhood'

# %% [markdown]
# #### step 6: summarise the cultural spaces by neighbourhood and purpose
#
# - use the pandas group_by() method to summarise the number of spaces by (known) neighbourhood and cultural purpose
