# %%
import pandas as pd

# %%
stations = pd.read_csv("Seattle_cycles_station.csv")

# %%
stations.describe()
# Out:
#              lat        long  install_dockcount  current_dockcount
# count  58.000000   58.000000          58.000000          58.000000
# mean   47.624796 -122.327242          17.586207          16.517241
# std     0.019066    0.014957           3.060985           5.117021
# min    47.598488 -122.355230          12.000000           0.000000
# 25%    47.613239 -122.338735          16.000000          16.000000
# 50%    47.618591 -122.328206          18.000000          18.000000
# 75%    47.627712 -122.316691          18.000000          18.000000
# max    47.666145 -122.284119          30.000000          26.000000

# %%
stations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   station_id         58 non-null     object
#  1   name               58 non-null     object
#  2   lat                58 non-null     float64
#  3   long               58 non-null     float64
#  4   install_date       58 non-null     object
#  5   install_dockcount  58 non-null     int64
#  6   modification_date  17 non-null     object
#  7   current_dockcount  58 non-null     int64
#  8   decommission_date  4 non-null      object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 4.2+ KB

# %%
stations.head(10)
# Out:
#   station_id                            name        lat        long  \
# 0      BT-01              3rd Ave & Broad St  47.618418 -122.350964
# 1      BT-03               2nd Ave & Vine St  47.615829 -122.348564
# 2      BT-04          6th Ave & Blanchard St  47.616094 -122.341102
# 3      BT-05          2nd Ave & Blanchard St  47.613110 -122.344208
# 4     CBD-03              7th Ave & Union St  47.610731 -122.332447
# 5     CBD-04              Union St & 4th Ave  47.609221 -122.335596
# 6     CBD-05             1st Ave & Marion St  47.604058 -122.335800
# 7     CBD-06             2nd Ave & Spring St  47.605950 -122.335768
# 8     CBD-07  City Hall / 4th Ave & James St  47.603509 -122.330409
# 9     CBD-13               2nd Ave & Pine St  47.610185 -122.339641
#
#   install_date  install_dockcount modification_date  current_dockcount  \
# 0   10/13/2014                 18               NaN                 18
# 1   10/13/2014                 16               NaN                 16
# ...

# %%
trips = pd.read_csv("Seattle_cycles_trip.csv")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10580\3193588831.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   trips = pd.read_csv("Seattle_cycles_trip.csv")

# %%
trips.head()
# Out:
#    trip_id         starttime          stoptime    bikeid  tripduration  \
# 0      431  10/13/2014 10:31  10/13/2014 10:48  SEA00298       985.935
# 1      432  10/13/2014 10:32  10/13/2014 10:48  SEA00195       926.375
# 2      433  10/13/2014 10:33  10/13/2014 10:48  SEA00486       883.831
# 3      434  10/13/2014 10:34  10/13/2014 10:48  SEA00333       865.937
# 4      435  10/13/2014 10:34  10/13/2014 10:49  SEA00202       923.923
#
#      from_station_name                                    to_station_name  \
# 0  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 1  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 2  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 3  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
# 4  2nd Ave & Spring St  Occidental Park / Occidental Ave S & S Washing...
#
#   from_station_id to_station_id usertype  gender birthyear
# ...

# %%
trips.isnull()
# Out:
#         trip_id  starttime  stoptime  bikeid  tripduration  from_station_name  \
# 0         False      False     False   False         False              False
# 1         False      False     False   False         False              False
# 2         False      False     False   False         False              False
# 3         False      False     False   False         False              False
# 4         False      False     False   False         False              False
# ...         ...        ...       ...     ...           ...                ...
# 286853    False      False     False   False         False              False
# 286854    False      False     False   False         False              False
# 286855    False      False     False   False         False              False
# 286856    False      False     False   False         False              False
# 286857    False      False     False   False         False              False
#
# ...

# %%
stations.isnull()
# Out:
#     station_id   name    lat   long  install_date  install_dockcount  \
# 0        False  False  False  False         False              False
# 1        False  False  False  False         False              False
# 2        False  False  False  False         False              False
# 3        False  False  False  False         False              False
# 4        False  False  False  False         False              False
# 5        False  False  False  False         False              False
# 6        False  False  False  False         False              False
# 7        False  False  False  False         False              False
# 8        False  False  False  False         False              False
# 9        False  False  False  False         False              False
# 10       False  False  False  False         False              False
# 11       False  False  False  False         False              False
# 12       False  False  False  False         False              False
# ...

# %%
stations[stations['name']==False].describe()
# Out:
#        lat  long  install_dockcount  current_dockcount
# count  0.0   0.0                0.0                0.0
# mean   NaN   NaN                NaN                NaN
# std    NaN   NaN                NaN                NaN
# min    NaN   NaN                NaN                NaN
# 25%    NaN   NaN                NaN                NaN
# 50%    NaN   NaN                NaN                NaN
# 75%    NaN   NaN                NaN                NaN
# max    NaN   NaN                NaN                NaN

# %%
stations.dropna()
# Out:
#    station_id                                       name        lat  \
# 10      CD-01                    12th Ave & E Yesler Way  47.602103
# 26      FH-01  Frye Art Museum / Terry Ave & Columbia St  47.607281
# 38     SLU-18                     Dexter Ave & Denny Way  47.618285
# 46      UW-01               UW McCarty Hall / Whitman Ct  47.660268
#
#           long install_date  install_dockcount modification_date  \
# 10 -122.316923    5/22/2015                 16          8/9/2016
# 26 -122.324783   10/13/2014                 16         3/18/2016
# 38 -122.342205   10/13/2014                 20         11/2/2015
# 46 -122.304826   10/13/2014                 16        10/29/2015
#
#     current_dockcount decommission_date
# 10                  0          8/9/2016
# 26                  0         3/18/2016
# 38                  0          7/2/2016
# 46                  0        10/29/2015

# %%
stations.head(10)
# Out:
#   station_id                            name        lat        long  \
# 0      BT-01              3rd Ave & Broad St  47.618418 -122.350964
# 1      BT-03               2nd Ave & Vine St  47.615829 -122.348564
# 2      BT-04          6th Ave & Blanchard St  47.616094 -122.341102
# 3      BT-05          2nd Ave & Blanchard St  47.613110 -122.344208
# 4     CBD-03              7th Ave & Union St  47.610731 -122.332447
# 5     CBD-04              Union St & 4th Ave  47.609221 -122.335596
# 6     CBD-05             1st Ave & Marion St  47.604058 -122.335800
# 7     CBD-06             2nd Ave & Spring St  47.605950 -122.335768
# 8     CBD-07  City Hall / 4th Ave & James St  47.603509 -122.330409
# 9     CBD-13               2nd Ave & Pine St  47.610185 -122.339641
#
#   install_date  install_dockcount modification_date  current_dockcount  \
# 0   10/13/2014                 18               NaN                 18
# 1   10/13/2014                 16               NaN                 16
# ...

# %%
stattrips=pd.concat([stations, trips], axis=1)

# %%
stattrips.head()
# Out:
#   station_id                    name        lat        long install_date  \
# 0      BT-01      3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1      BT-03       2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 2      BT-04  6th Ave & Blanchard St  47.616094 -122.341102   10/13/2014
# 3      BT-05  2nd Ave & Blanchard St  47.613110 -122.344208   10/13/2014
# 4     CBD-03      7th Ave & Union St  47.610731 -122.332447   10/13/2014
#
#    install_dockcount modification_date  current_dockcount decommission_date  \
# 0               18.0               NaN               18.0               NaN
# 1               16.0               NaN               16.0               NaN
# 2               16.0               NaN               16.0               NaN
# 3               14.0               NaN               14.0               NaN
# 4               20.0               NaN               20.0               NaN
#
# ...

# %%
search=stattrips[stattrips['gender']=='Male']

# %%
print (search)
# Out:
#        station_id                 name        lat        long install_date  \
# 0           BT-01   3rd Ave & Broad St  47.618418 -122.350964   10/13/2014
# 1           BT-03    2nd Ave & Vine St  47.615829 -122.348564   10/13/2014
# 4          CBD-03   7th Ave & Union St  47.610731 -122.332447   10/13/2014
# 5          CBD-04   Union St & 4th Ave  47.609221 -122.335596    7/27/2015
# 6          CBD-05  1st Ave & Marion St  47.604058 -122.335800   10/13/2014
# ...           ...                  ...        ...         ...          ...
# 286842        NaN                  NaN        NaN         NaN          NaN
# 286844        NaN                  NaN        NaN         NaN          NaN
# 286846        NaN                  NaN        NaN         NaN          NaN
# 286848        NaN                  NaN        NaN         NaN          NaN
# 286849        NaN                  NaN        NaN         NaN          NaN
#
#         install_dockcount modification_date  current_dockcount  \
# ...

# %%
search.head(10)
# Out:
#    station_id                            name        lat        long  \
# 0       BT-01              3rd Ave & Broad St  47.618418 -122.350964
# 1       BT-03               2nd Ave & Vine St  47.615829 -122.348564
# 4      CBD-03              7th Ave & Union St  47.610731 -122.332447
# 5      CBD-04              Union St & 4th Ave  47.609221 -122.335596
# 6      CBD-05             1st Ave & Marion St  47.604058 -122.335800
# 7      CBD-06             2nd Ave & Spring St  47.605950 -122.335768
# 9      CBD-13               2nd Ave & Pine St  47.610185 -122.339641
# 11      CH-01        Summit Ave & E Denny Way  47.618633 -122.325249
# 12      CH-02  E Harrison St & Broadway Ave E  47.622063 -122.321251
# 13      CH-03  Summit Ave E & E Republican St  47.623367 -122.325279
#
#    install_date  install_dockcount modification_date  current_dockcount  \
# 0    10/13/2014               18.0               NaN               18.0
# ...
