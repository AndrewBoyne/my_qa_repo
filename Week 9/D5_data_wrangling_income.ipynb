# %% [markdown]
# ## Wrangling Income reports by zipcode in Seattle
#
# ### Goals of the Task
#
#
#
# There is one table in the dataset retrieved from the Seattle open data portal for 2016 tax returns <br>
# *each row is a zipcode and income band. There are 6 bands with ranges of income defined* <br>
#
# - We want to use this data to estimate the average (weighted) income of people living in each zipcode. This may inform us if theres a connection between income levels in an area and cycle hire popularity / behaviour in that area.
# - we can also potentially use this data to work out how many working adults, non working adults and children, eldery people live in a zipcode. This could inform us how many potential cyclists live in each zipcode

# %% [markdown]
# #### Step 1 : use pandas to read the csv file as a data frame
# - import pandas as pd
# - use pandas read_csv
# - ensure you are pointing at the correct file path for the data sources (you may have to navigate in your notebook!)

# %%
import pandas as pd

# %%
income = pd.read_csv("WA_incomes_zip_code.csv")

# %%
income.head()
# Out:
#    Zip Code    Adjusted Gross Income  Number of returns  \
# 0     98001         $1 under $25,000               4420
# 1     98001    $25,000 under $50,000               3750
# 2     98001    $50,000 under $75,000               2520
# 3     98001   $75,000 under $100,000               1850
# 4     98001  $100,000 under $200,000               2680
#
#    Number of single returns  Number of joint returns  \
# 0                      3280                      530
# 1                      2130                      930
# 2                      1010                     1140
# 3                       430                     1250
# 4                       290                     2270
#
#    Number of head of household returns  Number with paid preparer's signature  \
# 0                                  560                                   1710
# 1                                  620                                   1570
# 2                                  340                                   1160
# 3                                  140                                    840
# 4                                  120                                   1280
#
#    Number of exemptions  Number of dependents  Total prepared returns  \
# 0                  5590                  1640                     140
# 1                  6990                  2350                      90
# 2                  5670                  2000                      30
# 3                  4600                  1500                       0
# 4                  7320                  2370                       0
#
#    Number of volunteer income tax assistance (VITA) prepared returns  \
# 0                                                100
# 1                                                 70
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Number of tax counseling for the elderly (TCE) prepared returns  \
# 0                                                 50
# 1                                                 30
# 2                                                 30
# 3                                                  0
# 4                                                  0
#
#    Number of volunteer prepared \nreturns with\nEarned Income Credit  \
# 0                                                 50
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Number of refund anticipation loan returns  \
# 0                                          40
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    Number of refund anticipation check returns  Number of elderly returns [3]  \
# 0                                          440                            640
# 1                                          580                            610
# 2                                          270                            570
# 3                                          170                            470
# 4                                          150                            650
#
#    Adjusted gross income (AGI) [4]  Number of returns.1  Total Income Amount
# 0                            54567                 4420                55475
# 1                           137006                 3750               138595
# 2                           156568                 2520               158094
# 3                           160704                 1850               162024
# 4                           359959                 2680               363321

# %% [markdown]
# #### Step 2: preview the dataframe using pandas functions like .info() .head(), .tail() and .describe()
# - look out for nulls and missing data
# - any problematic data types
# - interpret the column headers to see which columns you want to keep

# %%
income.columns=income.columns.str.lower()

# %%
income.head()
# Out:
#    zip code    adjusted gross income  number of returns  \
# 0     98001         $1 under $25,000               4420
# 1     98001    $25,000 under $50,000               3750
# 2     98001    $50,000 under $75,000               2520
# 3     98001   $75,000 under $100,000               1850
# 4     98001  $100,000 under $200,000               2680
#
#    number of single returns  number of joint returns  \
# 0                      3280                      530
# 1                      2130                      930
# 2                      1010                     1140
# 3                       430                     1250
# 4                       290                     2270
#
#    number of head of household returns  number with paid preparer's signature  \
# 0                                  560                                   1710
# 1                                  620                                   1570
# 2                                  340                                   1160
# 3                                  140                                    840
# 4                                  120                                   1280
#
#    number of exemptions  number of dependents  total prepared returns  \
# 0                  5590                  1640                     140
# 1                  6990                  2350                      90
# 2                  5670                  2000                      30
# 3                  4600                  1500                       0
# 4                  7320                  2370                       0
#
#    number of volunteer income tax assistance (vita) prepared returns  \
# 0                                                100
# 1                                                 70
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    number of tax counseling for the elderly (tce) prepared returns  \
# 0                                                 50
# 1                                                 30
# 2                                                 30
# 3                                                  0
# 4                                                  0
#
#    number of volunteer prepared \nreturns with\nearned income credit  \
# 0                                                 50
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    number of refund anticipation loan returns  \
# 0                                          40
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
#
#    number of refund anticipation check returns  number of elderly returns [3]  \
# 0                                          440                            640
# 1                                          580                            610
# 2                                          270                            570
# 3                                          170                            470
# 4                                          150                            650
#
#    adjusted gross income (agi) [4]  number of returns.1  total income amount
# 0                            54567                 4420                55475
# 1                           137006                 3750               138595
# 2                           156568                 2520               158094
# 3                           160704                 1850               162024
# 4                           359959                 2680               363321

# %%
sel_cols = ['zip code', 'adjusted gross income', 'adjusted gross income (agi) [4]', 'number of returns', 
            'number of dependents', 'number of elderly returns [3]']
income2=income[sel_cols]

# %%
income2.head(20)
# Out:
#     zip code    adjusted gross income  adjusted gross income (agi) [4]  \
# 0      98001         $1 under $25,000                            54567
# 1      98001    $25,000 under $50,000                           137006
# 2      98001    $50,000 under $75,000                           156568
# 3      98001   $75,000 under $100,000                           160704
# 4      98001  $100,000 under $200,000                           359959
# 5      98001         $200,000 or more                           179968
# 6      98002         $1 under $25,000                            73987
# 7      98002    $25,000 under $50,000                           186790
# 8      98002    $50,000 under $75,000                           149111
# 9      98002   $75,000 under $100,000                           109919
# 10     98002  $100,000 under $200,000                           146063
# 11     98002         $200,000 or more                            32388
# 12     98003         $1 under $25,000                           102269
# 13     98003    $25,000 under $50,000                           235025
# 14     98003    $50,000 under $75,000                           200376
# 15     98003   $75,000 under $100,000                           151757
# 16     98003  $100,000 under $200,000                           276121
# 17     98003         $200,000 or more                           159915
# 18     98004         $1 under $25,000                            34309
# 19     98004    $25,000 under $50,000                            85736
#
#     number of returns  number of dependents  number of elderly returns [3]
# 0                4420                  1640                            640
# 1                3750                  2350                            610
# 2                2520                  2000                            570
# 3                1850                  1500                            470
# 4                2680                  2370                            650
# 5                 540                   520                            160
# 6                5590                  3250                            930
# 7                5140                  4770                            790
# 8                2440                  2150                            520
# 9                1280                  1210                            320
# 10               1140                   910                            300
# 11                120                   100                             40
# 12               7790                  4100                           1280
# 13               6450                  5640                            970
# 14               3280                  3010                            760
# 15               1750                  1550                            480
# 16               2070                  1640                            620
# 17                400                   310                            150
# 18               3210                   480                            610
# 19               2300                   610                            450

# %% [markdown]
# #### Step 3: drop unneccessary columns
# - change all column headers to lower case
# - use any pandas method to select a subset of columns to a new dataframe
# - retain zipcode, adjusted gross income, number of returns, number of dependants, number of elderly returns

# %%
import numpy as np

# %%
income2.head(6)
# Out:
#    zip code    adjusted gross income  adjusted gross income (agi) [4]  \
# 0     98001         $1 under $25,000                            54567
# 1     98001    $25,000 under $50,000                           137006
# 2     98001    $50,000 under $75,000                           156568
# 3     98001   $75,000 under $100,000                           160704
# 4     98001  $100,000 under $200,000                           359959
# 5     98001         $200,000 or more                           179968
#
#    number of returns  number of dependents  number of elderly returns [3]
# 0               4420                  1640                            640
# 1               3750                  2350                            610
# 2               2520                  2000                            570
# 3               1850                  1500                            470
# 4               2680                  2370                            650
# 5                540                   520                            160

# %%
print (income2)
# Out:
#       zip code    adjusted gross income  adjusted gross income (agi) [4]  \
# 0        98001         $1 under $25,000                            54567
# 1        98001    $25,000 under $50,000                           137006
# 2        98001    $50,000 under $75,000                           156568
# 3        98001   $75,000 under $100,000                           160704
# 4        98001  $100,000 under $200,000                           359959
# ...        ...                      ...                              ...
# 2971     99999    $25,000 under $50,000                           532147
# 2972     99999    $50,000 under $75,000                           561159
# 2973     99999   $75,000 under $100,000                           501512
# 2974     99999  $100,000 under $200,000                          1052792
# 2975     99999         $200,000 or more                          1665460
#
#       number of returns  number of dependents  number of elderly returns [3]
# 0                  4420                  1640                            640
# 1                  3750                  2350                            610
# 2                  2520                  2000                            570
# 3                  1850                  1500                            470
# 4                  2680                  2370                            650
# ...                 ...                   ...                            ...
# 2971              14600                  8850                           4160
# 2972               9120                  5020                           3330
# 2973               5800                  3080                           2290
# 2974               7840                  4660                           3120
# 2975               2630                  1600                           1220
#
# [2976 rows x 6 columns]

# %%
income2['midpoint']=income2['adjusted gross income']
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5428\433851831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income2['midpoint']=income2['adjusted gross income']

# %%
income2
# Out:
#       zip code    adjusted gross income  adjusted gross income (agi) [4]  \
# 0        98001         $1 under $25,000                            54567
# 1        98001    $25,000 under $50,000                           137006
# 2        98001    $50,000 under $75,000                           156568
# 3        98001   $75,000 under $100,000                           160704
# 4        98001  $100,000 under $200,000                           359959
# ...        ...                      ...                              ...
# 2971     99999    $25,000 under $50,000                           532147
# 2972     99999    $50,000 under $75,000                           561159
# 2973     99999   $75,000 under $100,000                           501512
# 2974     99999  $100,000 under $200,000                          1052792
# 2975     99999         $200,000 or more                          1665460
#
#       number of returns  number of dependents  number of elderly returns [3]  \
# 0                  4420                  1640                            640
# 1                  3750                  2350                            610
# 2                  2520                  2000                            570
# 3                  1850                  1500                            470
# 4                  2680                  2370                            650
# ...                 ...                   ...                            ...
# 2971              14600                  8850                           4160
# 2972               9120                  5020                           3330
# 2973               5800                  3080                           2290
# 2974               7840                  4660                           3120
# 2975               2630                  1600                           1220
#
#                      midpoint
# 0            $1 under $25,000
# 1       $25,000 under $50,000
# 2       $50,000 under $75,000
# 3      $75,000 under $100,000
# 4     $100,000 under $200,000
# ...                       ...
# 2971    $25,000 under $50,000
# 2972    $50,000 under $75,000
# 2973   $75,000 under $100,000
# 2974  $100,000 under $200,000
# 2975         $200,000 or more
#
# [2976 rows x 7 columns]

# %% [markdown]
# #### step 4: create a column for middle income
#
# focusing on each income band, use the numpy where() function to populate a new column with the middle income of each range (with the exception of the final band, 200k+, which has no middle income of the range  - in these cases, you can use $250k as a suitable substitute)

# %%
dict = {
    "$1 under $25,000": 12500,
    "$25,000 under $50,000":37500,
    "$50,000 under $75,000":62500,
    "$75,000 under $100,000":87500,
    "$100,000 under $200,000":150000,
    "$200,000 or more":250000,
}

# %%
income2['midpoint']=income2.loc[:, 'adjusted gross income']
income2['midpoint'].replace(dict, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5428\3932697097.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income2['midpoint']=income2.loc[:, 'adjusted gross income']
# C:\Users\Admin\AppData\Local\Temp\ipykernel_5428\3932697097.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   income2['midpoint'].replace(dict, inplace=True)

# %%
income2
# Out:
#       zip code    adjusted gross income  adjusted gross income (agi) [4]  \
# 0        98001         $1 under $25,000                            54567
# 1        98001    $25,000 under $50,000                           137006
# 2        98001    $50,000 under $75,000                           156568
# 3        98001   $75,000 under $100,000                           160704
# 4        98001  $100,000 under $200,000                           359959
# ...        ...                      ...                              ...
# 2971     99999    $25,000 under $50,000                           532147
# 2972     99999    $50,000 under $75,000                           561159
# 2973     99999   $75,000 under $100,000                           501512
# 2974     99999  $100,000 under $200,000                          1052792
# 2975     99999         $200,000 or more                          1665460
#
#       number of returns  number of dependents  number of elderly returns [3]  \
# 0                  4420                  1640                            640
# 1                  3750                  2350                            610
# 2                  2520                  2000                            570
# 3                  1850                  1500                            470
# 4                  2680                  2370                            650
# ...                 ...                   ...                            ...
# 2971              14600                  8850                           4160
# 2972               9120                  5020                           3330
# 2973               5800                  3080                           2290
# 2974               7840                  4660                           3120
# 2975               2630                  1600                           1220
#
#       midpoint
# 0        12500
# 1        37500
# 2        62500
# 3        87500
# 4       150000
# ...        ...
# 2971     37500
# 2972     62500
# 2973     87500
# 2974    150000
# 2975    250000
#
# [2976 rows x 7 columns]

# %%
new_order=['zip code','adjusted gross income','midpoint','adjusted gross income (agi) [4]','number of returns','number of dependents',
          'number of elderly returns [3]']
income2 =income2[new_order]

# %%
income2.head(10)
# Out:
#    zip code    adjusted gross income  midpoint  \
# 0     98001         $1 under $25,000     12500
# 1     98001    $25,000 under $50,000     37500
# 2     98001    $50,000 under $75,000     62500
# 3     98001   $75,000 under $100,000     87500
# 4     98001  $100,000 under $200,000    150000
# 5     98001         $200,000 or more    250000
# 6     98002         $1 under $25,000     12500
# 7     98002    $25,000 under $50,000     37500
# 8     98002    $50,000 under $75,000     62500
# 9     98002   $75,000 under $100,000     87500
#
#    adjusted gross income (agi) [4]  number of returns  number of dependents  \
# 0                            54567               4420                  1640
# 1                           137006               3750                  2350
# 2                           156568               2520                  2000
# 3                           160704               1850                  1500
# 4                           359959               2680                  2370
# 5                           179968                540                   520
# 6                            73987               5590                  3250
# 7                           186790               5140                  4770
# 8                           149111               2440                  2150
# 9                           109919               1280                  1210
#
#    number of elderly returns [3]
# 0                            640
# 1                            610
# 2                            570
# 3                            470
# 4                            650
# 5                            160
# 6                            930
# 7                            790
# 8                            520
# 9                            320

# %%
(12500*4420)+(37500*3750)
# Out:
# 195875000

# %%
wa=(income2['midpoint']*income2['number of returns']).sum()/income2['number of returns'].sum(), groupby

# %%
def weighted_average(dataframe, value, weight):
    val=dataframe[value]
    wt=dataframe[weight]
    return (val*wt).sum()/wt.sum()

# %%
newdf=income2.groupby('zip code').apply(weighted_average,
                                  'midpoint','number of returns')

# %% [markdown]
# #### Step 5: calculations and aggregations
# - using the number of returns and the middle income of each band, calculate a weighted average income per zipcode in a new dataframe
# - add to this data frame the number of returns per zipcode
# - add to this dataframe the aggregated number of dependents per zipcode
# - add to this dataframe the aggregated number of elderly per zipcode

# %%
wa_per_zip = newdf.to_frame()

# %%
wa_per_zip.head()
# Out:
#           weighted_average
# zip code
# 98001         66767.131980
# 98002         46347.867600
# 98003         50960.211592
# 98004        117667.717890
# 98005        101977.107180

# %%
wa_per_zip.rename(columns={0:'weighted_average'}, inplace=True)

# %%
print (wa_per_zip)
# Out:
#           weighted_average
# zip code
# 98001         66767.131980
# 98002         46347.867600
# 98003         50960.211592
# 98004        117667.717890
# 98005        101977.107180
# ...                    ...
# 99371         41666.666667
# 99401         45833.333333
# 99402         55537.974684
# 99403         53117.913832
# 99999         62979.866917
#
# [496 rows x 1 columns]

# %% [markdown]
# #### Step 6: validate the data
# - use EDA techniques including visualisation to validate your calculations and aggregations from the previous step
