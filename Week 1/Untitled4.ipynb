# %%
import pandas as pd #standard opening
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("iris_dataset.csv") # to open a df in the same folder

# %%
df.head(1) # to see the top (x) rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
#
#    target  New_DColumn  New_Column
# 0       0            0          12

# %%
df.tail(1) # to see the botom x rows
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 149                5.9               3.0                5.1               1.8
#
#      target  New_DColumn  New_Column
# 149       2            0          12

# %%
df['New_Column']=12 # adds a new column to the df (inspace = True) 
# would keep the new column in the original df

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df['New_column']= Col_data
#
# NameError: name 'Col_data' is not defined

# %%
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  New_DColumn  New_Column
# 0       0            0          12
# 1       0            0          12
# 2       0            0          12
# 3       0            0          12
# 4       0            0          12

# %%
df.rank(1) # ranks the df based on the column I choose
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  6.0               5.0                4.0               3.0
# 1                  6.0               5.0                4.0               3.0
# 2                  6.0               5.0                4.0               3.0
# 3                  6.0               5.0                4.0               3.0
# 4                  6.0               5.0                4.0               3.0
# ..                 ...               ...                ...               ...
# 145                6.0               4.0                5.0               3.0
# 146                6.0               4.0                5.0               2.0
# 147                6.0               4.0                5.0               2.5
# 148                6.0               4.0                5.0               3.0
# 149                6.0               4.0                5.0               2.0
#
# ...

# %%
df.sort_values(by='sepal width (cm)', ascending = True).head() # sorts by the chosen column
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 60                 5.0               2.0                3.5               1.0
# 62                 6.0               2.2                4.0               1.0
# 119                6.0               2.2                5.0               1.5
# 68                 6.2               2.2                4.5               1.5
# 41                 4.5               2.3                1.3               0.3
#
#      target  New_DColumn  New_Column
# 60        1            0          12
# 62        1            0          12
# 119       2            0          12
# 68        1            0          12
# 41        0            0          12

# %%
df.sort_values(by='sepal width (cm)', ascending = False).head() # sorts as above 
#but descending
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 15                5.7               4.4                1.5               0.4
# 33                5.5               4.2                1.4               0.2
# 32                5.2               4.1                1.5               0.1
# 14                5.8               4.0                1.2               0.2
# 16                5.4               3.9                1.3               0.4
#
#     target  New_DColumn  New_Column
# 15       0            0          12
# 33       0            0          12
# 32       0            0          12
# 14       0            0          12
# 16       0            0          12

# %%
df1=[['row0', 'row1', 'row2']] # creates a brand new df

# %%
df1
# Out:
# [['row0', 'row1', 'row2']]

# %%
top5_rows=df.head(5) # creates a new df with the number of rows I 
# determine in the brackets

# %%
top5_rows
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  New_DColumn  New_Column
# 0       0            0          12
# 1       0            0          12
# 2       0            0          12
# 3       0            0          12
# 4       0            0          12

# %%
top5_rows.drop('New_DColumn', axis=1) # removes the selected column
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target  New_Column
# 0       0          12
# 1       0          12
# 2       0          12
# 3       0          12
# 4       0          12

# %%
df.columns=['Column 1', 'Column 2', 'Column 3', 'Column 4', 'Column 5', 'Column 6', 'Column 7',]
# changes the names of the columns

# %%
df
# Out:
#      Column 1  Column 2  Column 3  Column 4  Column 5  Column 6  Column 7
# 0         5.1       3.5       1.4       0.2         0         0        12
# 1         4.9       3.0       1.4       0.2         0         0        12
# 2         4.7       3.2       1.3       0.2         0         0        12
# 3         4.6       3.1       1.5       0.2         0         0        12
# 4         5.0       3.6       1.4       0.2         0         0        12
# ..        ...       ...       ...       ...       ...       ...       ...
# 145       6.7       3.0       5.2       2.3         2         0        12
# 146       6.3       2.5       5.0       1.9         2         0        12
# 147       6.5       3.0       5.2       2.0         2         0        12
# 148       6.2       3.4       5.4       2.3         2         0        12
# 149       5.9       3.0       5.1       1.8         2         0        12
#
# [150 rows x 7 columns]

# %%
df = pd.read_csv("iris_dataset.csv")

# %%
df.head(5)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.shape # give the overall size of the df = 150 rows, 5 columns
# Out:
# (150, 5)

# %%
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.count() # gives number of non Null values
# Out:
# sepal length (cm)    150
# sepal width (cm)     150
# petal length (cm)    150
# petal width (cm)     150
# target               150
# dtype: int64

# %%
# Out:
#   Cell In[43], line 1
#     df['New_Column']=?
#                      ^
# SyntaxError: invalid syntax

# %%
df.min() # finds minimum values from the df
# Out:
# sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# target               0.0
# dtype: float64

# %%
df.max()
# Out:
# sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# target               2.0
# dtype: float64

# %%
df.mean()
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# target               1.000000
# dtype: float64

# %%
df.median()
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# target               1.00
# dtype: float64

# %%
df.describe() # gives all SD values
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
df[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)' ]] 
# and so on
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)
# 0                  5.1               3.5                1.4
# 1                  4.9               3.0                1.4
# 2                  4.7               3.2                1.3
# 3                  4.6               3.1                1.5
# 4                  5.0               3.6                1.4
# ..                 ...               ...                ...
# 145                6.7               3.0                5.2
# 146                6.3               2.5                5.0
# 147                6.5               3.0                5.2
# 148                6.2               3.4                5.4
# 149                5.9               3.0                5.1
#
# [150 rows x 3 columns]

# %%
df['sepal length (cm)'].where(df['sepal length (cm)'] > 6.5) 
# returns rows where the query is satisfied (Boolean)
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 145    6.7
# 146    NaN
# 147    NaN
# 148    NaN
# 149    NaN
# Name: sepal length (cm), Length: 150, dtype: float64

# %%
pd.merge(df, dfx, how='left', on 'column')
# merges 2 dfs with the same column, can be right, inner, outer

# %%
df.target.unique() #unique values in the column
# Out:
# array([0, 1, 2], dtype=int64)

# %%
df.target.value_counts() # number of unique values in the column
# Out:
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64

# %%
df.isnull()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                False             False              False             False
# 1                False             False              False             False
# 2                False             False              False             False
# 3                False             False              False             False
# 4                False             False              False             False
# ..                 ...               ...                ...               ...
# 145              False             False              False             False
# 146              False             False              False             False
# 147              False             False              False             False
# 148              False             False              False             False
# 149              False             False              False             False
#
#      target
# 0     False
# ...

# %%
grouped=df.groupby(['petal width (cm)'])

# %%
grouped.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 140                6.7               3.1                5.6               2.4
# 141                6.9               3.1                5.1               2.3
# 142                5.8               2.7                5.1               1.9
# 144                6.7               3.3                5.7               2.5
# 146                6.3               2.5                5.0               1.9
#
#      target
# 0         0
# ...
