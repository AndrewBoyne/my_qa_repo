# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\Admin\\Desktop\\LBG_incubation_data\\Direct_Marketing_Campaign.csv')

# %%
df.head()
# Out:
#    Age           Job Marital Status  Education Credit  Balance Housing Loan  \
# 0   58    management        married   tertiary     no     2143          yes
# 1   44    technician         single  secondary     no       29          yes
# 2   33  entrepreneur        married  secondary     no        2          yes
# 3   47   blue-collar        married    unknown     no     1506          yes
# 4   33       unknown         single    unknown     no        1           no
#
#   Personal Loan Contact type  Last Contact Day Last Contact Month  \
# 0            no      unknown                 5                may
# 1            no      unknown                 5                may
# 2           yes      unknown                 5                may
# 3            no      unknown                 5                may
# 4            no      unknown                 5                may
#
#    Last Contact Duration  Campaign Freq  Lag in days  Previous Freq  \
# ...

# %%
df.head()
# Out:
#    Age           Job Marital Status  Education Credit  Balance Housing Loan  \
# 0   58    management        married   tertiary     no     2143          yes
# 1   44    technician         single  secondary     no       29          yes
# 2   33  entrepreneur        married  secondary     no        2          yes
# 3   47   blue-collar        married    unknown     no     1506          yes
# 4   33       unknown         single    unknown     no        1           no
#
#   Personal Loan Contact type  Last Contact Day Last Contact Month  \
# 0            no      unknown                 5                may
# 1            no      unknown                 5                may
# 2           yes      unknown                 5                may
# 3            no      unknown                 5                may
# 4            no      unknown                 5                may
#
#    Last Contact Duration  Campaign Freq  Lag in days  Previous Freq  \
# ...

# %%
df['Subscription'] = df['Subscription'].replace({1: 'No', 2: 'Yes'})

# %%
df.head()
# Out:
#    Age           Job Marital Status  Education Credit  Balance Housing Loan  \
# 0   58    management        married   tertiary     no     2143          yes
# 1   44    technician         single  secondary     no       29          yes
# 2   33  entrepreneur        married  secondary     no        2          yes
# 3   47   blue-collar        married    unknown     no     1506          yes
# 4   33       unknown         single    unknown     no        1           no
#
#   Personal Loan Contact type  Last Contact Day Last Contact Month  \
# 0            no      unknown                 5                may
# 1            no      unknown                 5                may
# 2           yes      unknown                 5                may
# 3            no      unknown                 5                may
# 4            no      unknown                 5                may
#
#    Last Contact Duration  Campaign Freq  Lag in days  Previous Freq  \
# ...

# %%
df = df.rename(columns={'Subscription': 'Accepted Offer?'})

# %%
df.tail()
# Out:
#        Age           Job Marital Status  Education Credit  Balance  \
# 45206   51    technician        married   tertiary     no      825
# 45207   71       retired       divorced    primary     no     1729
# 45208   72       retired        married  secondary     no     5715
# 45209   57   blue-collar        married  secondary     no      668
# 45210   37  entrepreneur        married  secondary     no     2971
#
#       Housing Loan Personal Loan Contact type  Last Contact Day  \
# 45206           no            no     cellular                17
# 45207           no            no     cellular                17
# 45208           no            no     cellular                17
# 45209           no            no    telephone                17
# 45210           no            no     cellular                17
#
#       Last Contact Month  Last Contact Duration  Campaign Freq  Lag in days  \
# 45206                nov                    977              3           -1
# ...

# %%
df.to_csv('DM_Campaign2.csv')
