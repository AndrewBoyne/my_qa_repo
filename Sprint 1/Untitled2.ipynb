# %%
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\Admin\\Documents\\GitHub\\my_qa_repo\\Sprint 1\\DM_Campaign2.csv')

# %%
df
# Out:
#        Unnamed: 0  Age           Job Marital Status  Education Credit  \
# 0               0   58    management        married   tertiary     no
# 1               1   44    technician         single  secondary     no
# 2               2   33  entrepreneur        married  secondary     no
# 3               3   47   blue-collar        married    unknown     no
# 4               4   33       unknown         single    unknown     no
# ...           ...  ...           ...            ...        ...    ...
# 45206       45206   51    technician        married   tertiary     no
# 45207       45207   71       retired       divorced    primary     no
# 45208       45208   72       retired        married  secondary     no
# 45209       45209   57   blue-collar        married  secondary     no
# 45210       45210   37  entrepreneur        married  secondary     no
#
#        Balance Housing Loan Personal Loan Contact type  Last Contact Day  \
# ...

# %%
value_in_category1='telephone'
threshold_value_in_value_column=60
segment=df[(df['Contact type']==value_in_category1) & (df['Age'] > threshold_value_in_value_column)]

# %%
segment
# Out:
#        Unnamed: 0  Age           Job Marital Status  Education Credit  \
# 21370       21370   61       retired        married    primary     no
# 29158       29158   83       retired        married    primary     no
# 29221       29221   61     housemaid         single    unknown     no
# 29382       29382   65       retired        married    primary     no
# 29610       29610   69       retired        married    primary     no
# ...           ...  ...           ...            ...        ...    ...
# 45091       45091   61       retired        married    primary     no
# 45104       45104   73       retired        married    primary     no
# 45140       45140   63  entrepreneur        married  secondary     no
# 45141       45141   77       unknown        married    unknown     no
# 45154       45154   63       retired        married    primary     no
#
#        Balance Housing Loan Personal Loan Contact type  Last Contact Day  \
# ...

# %%
df.to_csv('oldwithphone.csv')

# %%
segment.rename(columns={'Contact type':'Telphone only'}, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10468\2295864730.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   segment.rename(columns={'Contact type':'Telphone only'}, inplace=True)

# %%
segment
# Out:
#        Unnamed: 0  Age           Job Marital Status  Education Credit  \
# 21370       21370   61       retired        married    primary     no
# 29158       29158   83       retired        married    primary     no
# 29221       29221   61     housemaid         single    unknown     no
# 29382       29382   65       retired        married    primary     no
# 29610       29610   69       retired        married    primary     no
# ...           ...  ...           ...            ...        ...    ...
# 45091       45091   61       retired        married    primary     no
# 45104       45104   73       retired        married    primary     no
# 45140       45140   63  entrepreneur        married  secondary     no
# 45141       45141   77       unknown        married    unknown     no
# 45154       45154   63       retired        married    primary     no
#
#        Balance Housing Loan Personal Loan Telphone only  Last Contact Day  \
# ...

# %%
segment.to_csv('telephone_only.csv')

# %%
segment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 372 entries, 21370 to 45154
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             372 non-null    int64
#  1   Age                    372 non-null    int64
#  2   Job                    372 non-null    object
#  3   Marital Status         372 non-null    object
#  4   Education              372 non-null    object
#  5   Credit                 372 non-null    object
#  6   Balance                372 non-null    int64
#  7   Housing Loan           372 non-null    object
#  8   Personal Loan          372 non-null    object
#  9   Telphone only          372 non-null    object
#  10  Last Contact Day       372 non-null    int64
#  11  Last Contact Month     372 non-null    object
#  12  Last Contact Duration  372 non-null    int64
#  13  Campaign Freq          372 non-null    int64
# ...

# %%
value_counts=segment['Accepted Offer?'].value_counts()

# %%
value_counts
# Out:
# No     230
# Yes    142
# Name: Accepted Offer?, dtype: int64

# %%
#value_in_category1='telephone'
#threshold_value_in_value_column=60
#segment=df[(df['Contact type']==value_in_category1) & (df['Age'] > threshold_value_in_value_column)]

# %%
value_in_categoryA='management'
values_in_categoryB=['secondary', 'tertiary']
min_valueC=30
max_valueC=35
segmentA=df[(df['Job']==value_in_categoryA) &
           (df['Education'].isin(values_in_categoryB)) &
           (df['Age'] >= min_valueC) &
           (df['Age'] >= max_valueC)]

# %%
segmentA
# Out:
#        Unnamed: 0  Age         Job Marital Status  Education Credit  Balance  \
# 0               0   58  management        married   tertiary     no     2143
# 5               5   35  management        married   tertiary     no      231
# 21             21   56  management        married   tertiary     no      779
# 26             26   39  management         single   tertiary     no      255
# 28             28   46  management         single  secondary     no     -246
# ...           ...  ...         ...            ...        ...    ...      ...
# 45156       45156   37  management        married   tertiary     no     3556
# 45194       45194   59  management        married   tertiary     no      138
# 45197       45197   36  management         single  secondary     no     1511
# 45198       45198   37  management        married   tertiary     no     1428
# 45201       45201   53  management        married   tertiary     no      583
#
# ...

# %%
df.to_csv('Education_and_job_segment.csv')
